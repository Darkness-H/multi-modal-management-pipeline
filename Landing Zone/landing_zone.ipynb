# %% [markdown]
# ## Landing Zone

# %%
# Importing useful dependencies
import io
import ast
import time
import boto3
import requests
import mimetypes
from io import BytesIO
from botocore.client import Config
from datasets import load_dataset

# %%
# Setup S3 client for MinIO (MinIO implements Amazon S3 API)
s3 = boto3.client(
    "s3",
    endpoint_url="http://127.0.0.1:9000", # MinIO API endpoint
    aws_access_key_id="minioadmin", # User name
    aws_secret_access_key="minioadmin", # Password
)

# %%
# List existing buckets
buckets = [b["Name"] for b in s3.list_buckets()["Buckets"]]

# Function that given a name, creates a bucket
def createBucket(name, list_buckets):
    if name in list_buckets:
        print(f"Bucket '{name}' already exists!")
    else:
        s3.create_bucket(Bucket=name)
        print(f"Created bucket: {name}")

# Create a bucket named landing_zone
createBucket("landing-zone", buckets)
# Out:
# Created bucket: landing-zone

# %%
# Create two sub-buckets inside landing_zone.
# Strictly speaking, we cannot cannot create a bucket inside another one, so we will create it like a folder.
s3.put_object(Bucket="landing-zone", Key="temporal-landing/") # Sub-bucket Temporal Landing
s3.put_object(Bucket="landing-zone", Key="persistent-landing/") # Sub-bucket Presistent Landing
# Out:
# {'ResponseMetadata': {'RequestId': '1868DC1A77801D09',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '0',
#    'etag': '"d41d8cd98f00b204e9800998ecf8427e"',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-checksum-crc32': 'AAAAAA==',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '1868DC1A77801D09',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '1976',
#    'x-ratelimit-remaining': '1976',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Fri, 26 Sep 2025 14:41:00 GMT'},
#   'RetryAttempts': 0},
#  'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#  'ChecksumCRC32': 'AAAAAA==',
#  'ChecksumType': 'FULL_OBJECT'}

# %% [markdown]
# ### Temporal Landing

# %%
# We are going to use two datasets, one from: https://huggingface.co/datasets/FronkonGames/steam-games-dataset (123 MB)
ds1_raw = load_dataset("FronkonGames/steam-games-dataset")
# The other one from: https://huggingface.co/datasets/atalaydenknalbant/rawg-games-dataset (998 MB)
ds2_raw = load_dataset("atalaydenknalbant/rawg-games-dataset")

# Print the number of rows of each dataset
print(f"The dataset 1 contains {ds1_raw['train'].num_rows} rows")
print(f"The dataset 2 contains {ds2_raw['train'].num_rows} rows")
# Out:
# The dataset 1 contains 83560 rows
# The dataset 2 contains 889793 rows
# C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\table.py:1421: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)

# %%
# We are going to use the first 100 rows from each dataset for testing purposes
ds1 = ds1_raw['train'][0:100]
ds2 = ds2_raw['train'][0:100]

# Print the number of rows of each subdataset
print(f"The subdataset 1 contains {len(ds1['About the game'])} rows")
print(f"The subdataset 2 contains {len(ds2['description'])} rows")
# Out:
# The subdataset 1 contains 100 rows
# The subdataset 2 contains 100 rows

# %%
# We are interested on Text, Image and Video data
# We can find each of these data in the following columns
# ds1: "About the game" (Text), "Header image" (Image), "Screenshots" (Image), "Movies" (Video)
# ds2: "description" (Text), "background_image" (Image), "background_image_additional" (Image), "short_screenshots" (Image)
# By combing both datasets, we assume there will be duplicates of games

# %% [markdown]
# **Uploading Texts**

# %%
def upload_strings_separately(bucket_name, client, strings, path="temporal-landing/", prefix="text"):
    for i, s in enumerate(strings, start=1):
        if not s: # skip empty strings or None
            continue
        object_name = f"{path}{prefix}_{i}.txt" # temporal-landing/text_1.txt, temporal-landing/text_2.txt ...
        client.put_object(
            Bucket=bucket_name,
            Key=object_name,
            Body=io.BytesIO(s.encode("utf-8")),
            ContentType="text/plain"
        )

# Uploading text files (combining both datasets)
upload_strings_separately("landing-zone", s3, strings = 
                          ds1['About the game'] +
                          ds2['description'],
                          path = "temporal-landing/")

# %% [markdown]
# **Uploading Images**

# %%
# The fields "Screenshots" from ds1 and "short_screenshots" from ds2 need to be cleaned first.

# ds1
ds1ss = [] # Flatten into a clean list of URLs
for item in ds1['Screenshots']:
    if not item:
        continue
    ds1ss.extend([url.strip() for url in item.split(",") if url.strip()])

# ds2
ds2ss = [] # Extract image URLs
for elem in ds2['short_screenshots']:
    if not elem:
        continue
    records = elem.split('|') # Split the string by '|'
    for rec in records:
        # Convert string to dict safely
        d = ast.literal_eval(rec)
        ds2ss.append(d['image'])

# %%
def upload_media_from_links(bucket_name, client, links, path="temporal-landing/", prefix="image"):
    for i, url in enumerate(links, start=1):
        if not url:
            continue
        
        # Stream download to avoid loading full file in memory
        with requests.get(url, stream=True, timeout=60) as r:
            r.raise_for_status() # check for HTTP errors
            ext = url.split('.')[-1].split('?')[0] # get file extension
            object_name = f"{path}{prefix}_{i}.{ext}"
            # This streams the request directly to MinIO without creating a full BytesIO object
            client.upload_fileobj(
                Fileobj=r.raw,
                Bucket=bucket_name,
                Key=object_name,
                ExtraArgs={"ContentType": f"{prefix}/{ext}"}
            )

# %%
# Uploading image files (combining both datasets)
upload_media_from_links("landing-zone", s3, links = 
                         ds1['Header image'] + ds2['background_image'], #+ ds2['background_image_additional'] + ds1ss + ds2ss,
                         path="temporal-landing/")

# %% [markdown]
# **Uploading Videos**

# %%
# Uploading video files
upload_media_from_links("landing-zone", s3, links = 
                         ds1['Movies'][0:5], # We can only upload a few videos due to MinioIO storage size
                         path="temporal-landing/", prefix = "video")

# %% [markdown]
# ### Persistent Landing

# %%
# Create three sub-buckets inside persistent-landing, one per format
s3.put_object(Bucket="landing-zone", Key="persistent-landing/texts/") # Sub-bucket Text
s3.put_object(Bucket="landing-zone", Key="persistent-landing/images/") # Sub-bucket Image
s3.put_object(Bucket="landing-zone", Key="persistent-landing/videos/") # Sub-bucket Video
# Out:
# {'ResponseMetadata': {'RequestId': '1868DC42CAE4BE8B',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '0',
#    'etag': '"d41d8cd98f00b204e9800998ecf8427e"',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-checksum-crc32': 'AAAAAA==',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '1868DC42CAE4BE8B',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '1976',
#    'x-ratelimit-remaining': '1976',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Fri, 26 Sep 2025 14:43:53 GMT'},
#   'RetryAttempts': 0},
#  'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#  'ChecksumCRC32': 'AAAAAA==',
#  'ChecksumType': 'FULL_OBJECT'}

# %%
def classify_object_by_head(client, bucket, key):
    """
    Return 'texts', 'images' or 'videos' by inspecting file ContentType.
    """
    # ask S3 for ContentType
    head = client.head_object(Bucket=bucket, Key=key)
    ct = head.get("ContentType", "")
    if ct.startswith("text/"):
        return "texts"
    elif ct.startswith("image/"):
        return "images"
    elif ct.startswith("video/"):
        return "videos"

def move_files(client, bucket,
               source_prefix="temporal-landing/",
               dest_prefix="persistent-landing/"):
    """
    Move (copy then delete) all objects under source_prefix to dest_prefix,
    routing text -> dest_prefix/texts/, image -> persistent/images/, video -> dest_prefix/videos/.
    """
    paginator = client.get_paginator("list_objects_v2") # It returns objects in pages and not all at once.

    for page in paginator.paginate(Bucket=bucket, Prefix=source_prefix):
        for obj in page.get("Contents", []):

            if obj['Size'] == 0:
                continue
            
            src_key = obj["Key"]

            # classify
            category = classify_object_by_head(client, bucket, src_key)

            # get file extension
            ext = src_key.split('.')[-1].split('?')[0]

            # new filename = timestamp + original extension
            ts = int(time.time() * 1000)  # milliseconds
            new_filename = f"{category[0:-1]}_{ts}.{ext}"

            # build destination key
            dest_key = f"{dest_prefix}{category}/{new_filename}"

            # copy then delete
            client.copy_object(Bucket=bucket, CopySource={"Bucket": bucket, "Key": src_key}, Key=dest_key)
            client.delete_object(Bucket=bucket, Key=src_key)

            print(f"Moved: {src_key} -> {dest_key}")

# %%
int(time.time() * 1000)
# Out:
# 1758898578836

# %%
move_files(s3, "landing-zone", "temporal-landing/", "persistent-landing/")
# Out:
# Moved: temporal-landing/image_1.jpg -> persistent-landing/images/image_1758897834623.jpg
# Moved: temporal-landing/image_10.jpg -> persistent-landing/images/image_1758897834678.jpg
# Moved: temporal-landing/image_100.jpg -> persistent-landing/images/image_1758897834707.jpg
# Moved: temporal-landing/image_101.jpg -> persistent-landing/images/image_1758897834735.jpg
# Moved: temporal-landing/image_102.jpg -> persistent-landing/images/image_1758897834767.jpg
# Moved: temporal-landing/image_103.jpg -> persistent-landing/images/image_1758897834797.jpg
# Moved: temporal-landing/image_104.jpg -> persistent-landing/images/image_1758897834823.jpg
# Moved: temporal-landing/image_105.jpg -> persistent-landing/images/image_1758897834854.jpg
# Moved: temporal-landing/image_106.jpg -> persistent-landing/images/image_1758897834881.jpg
# Moved: temporal-landing/image_107.jpg -> persistent-landing/images/image_1758897834909.jpg
# Moved: temporal-landing/image_108.jpg -> persistent-landing/images/image_1758897834935.jpg
# Moved: temporal-landing/image_109.jpg -> persistent-landing/images/image_1758897834966.jpg
# Moved: temporal-landing/image_11.jpg -> persistent-landing/images/image_1758897834994.jpg
# Moved: temporal-landing/image_110.jpg -> persistent-landing/images/image_1758897835022.jpg
# Moved: temporal-landing/image_111.jpg -> persistent-landing/images/image_1758897835058.jpg
# Moved: temporal-landing/image_112.jpg -> persistent-landing/images/image_1758897835087.jpg
# Moved: temporal-landing/image_113.jpg -> persistent-landing/images/image_1758897835115.jpg
# Moved: temporal-landing/image_114.jpg -> persistent-landing/images/image_1758897835146.jpg
# Moved: temporal-landing/image_115.jpg -> persistent-landing/images/image_1758897835174.jpg
# Moved: temporal-landing/image_116.jpg -> persistent-landing/images/image_1758897835200.jpg
# Moved: temporal-landing/image_117.jpg -> persistent-landing/images/image_1758897835225.jpg
# Moved: temporal-landing/image_118.jpg -> persistent-landing/images/image_1758897835251.jpg
# Moved: temporal-landing/image_119.jpg -> persistent-landing/images/image_1758897835279.jpg
# Moved: temporal-landing/image_12.jpg -> persistent-landing/images/image_1758897835305.jpg
# Moved: temporal-landing/image_120.jpg -> persistent-landing/images/image_1758897835330.jpg
# Moved: temporal-landing/image_121.jpg -> persistent-landing/images/image_1758897835359.jpg
# Moved: temporal-landing/image_122.jpg -> persistent-landing/images/image_1758897835388.jpg
# Moved: temporal-landing/image_123.jpg -> persistent-landing/images/image_1758897835418.jpg
# Moved: temporal-landing/image_124.jpg -> persistent-landing/images/image_1758897835442.jpg
# Moved: temporal-landing/image_125.jpg -> persistent-landing/images/image_1758897835468.jpg
# Moved: temporal-landing/image_126.jpg -> persistent-landing/images/image_1758897835494.jpg
# Moved: temporal-landing/image_127.jpg -> persistent-landing/images/image_1758897835525.jpg
# Moved: temporal-landing/image_128.jpg -> persistent-landing/images/image_1758897835551.jpg
# Moved: temporal-landing/image_129.jpg -> persistent-landing/images/image_1758897835580.jpg
# Moved: temporal-landing/image_13.jpg -> persistent-landing/images/image_1758897835608.jpg
# Moved: temporal-landing/image_130.jpg -> persistent-landing/images/image_1758897835635.jpg
# Moved: temporal-landing/image_131.jpg -> persistent-landing/images/image_1758897835664.jpg
# Moved: temporal-landing/image_132.jpg -> persistent-landing/images/image_1758897835697.jpg
# Moved: temporal-landing/image_133.jpg -> persistent-landing/images/image_1758897835723.jpg
# Moved: temporal-landing/image_134.jpg -> persistent-landing/images/image_1758897835755.jpg
# Moved: temporal-landing/image_135.jpg -> persistent-landing/images/image_1758897835783.jpg
# Moved: temporal-landing/image_136.jpg -> persistent-landing/images/image_1758897835805.jpg
# Moved: temporal-landing/image_137.jpg -> persistent-landing/images/image_1758897835833.jpg
# Moved: temporal-landing/image_138.jpg -> persistent-landing/images/image_1758897835859.jpg
# Moved: temporal-landing/image_139.jpg -> persistent-landing/images/image_1758897835881.jpg
# Moved: temporal-landing/image_14.jpg -> persistent-landing/images/image_1758897835903.jpg
# Moved: temporal-landing/image_140.jpg -> persistent-landing/images/image_1758897835927.jpg
# Moved: temporal-landing/image_141.jpg -> persistent-landing/images/image_1758897835981.jpg
# Moved: temporal-landing/image_142.jpg -> persistent-landing/images/image_1758897836004.jpg
# Moved: temporal-landing/image_143.jpg -> persistent-landing/images/image_1758897836030.jpg
# Moved: temporal-landing/image_144.jpg -> persistent-landing/images/image_1758897836057.jpg
# Moved: temporal-landing/image_145.jpg -> persistent-landing/images/image_1758897836087.jpg
# Moved: temporal-landing/image_146.jpg -> persistent-landing/images/image_1758897836134.jpg
# Moved: temporal-landing/image_147.jpg -> persistent-landing/images/image_1758897836161.jpg
# Moved: temporal-landing/image_148.jpg -> persistent-landing/images/image_1758897836186.jpg
# Moved: temporal-landing/image_149.jpg -> persistent-landing/images/image_1758897836211.jpg
# Moved: temporal-landing/image_15.jpg -> persistent-landing/images/image_1758897836238.jpg
# Moved: temporal-landing/image_150.jpg -> persistent-landing/images/image_1758897836260.jpg
# Moved: temporal-landing/image_151.jpg -> persistent-landing/images/image_1758897836284.jpg
# Moved: temporal-landing/image_152.jpg -> persistent-landing/images/image_1758897836318.jpg
# Moved: temporal-landing/image_153.jpg -> persistent-landing/images/image_1758897836344.jpg
# Moved: temporal-landing/image_154.jpg -> persistent-landing/images/image_1758897836371.jpg
# Moved: temporal-landing/image_155.jpg -> persistent-landing/images/image_1758897836397.jpg
# Moved: temporal-landing/image_156.jpg -> persistent-landing/images/image_1758897836422.jpg
# Moved: temporal-landing/image_157.jpg -> persistent-landing/images/image_1758897836447.jpg
# Moved: temporal-landing/image_158.jpg -> persistent-landing/images/image_1758897836484.jpg
# Moved: temporal-landing/image_159.jpg -> persistent-landing/images/image_1758897836515.jpg
# Moved: temporal-landing/image_16.jpg -> persistent-landing/images/image_1758897836546.jpg
# Moved: temporal-landing/image_160.jpg -> persistent-landing/images/image_1758897836569.jpg
# Moved: temporal-landing/image_161.jpg -> persistent-landing/images/image_1758897836594.jpg
# Moved: temporal-landing/image_162.jpg -> persistent-landing/images/image_1758897836619.jpg
# Moved: temporal-landing/image_163.jpg -> persistent-landing/images/image_1758897836675.jpg
# Moved: temporal-landing/image_164.jpg -> persistent-landing/images/image_1758897836700.jpg
# Moved: temporal-landing/image_165.jpg -> persistent-landing/images/image_1758897836724.jpg
# Moved: temporal-landing/image_166.jpg -> persistent-landing/images/image_1758897836748.jpg
# Moved: temporal-landing/image_167.jpg -> persistent-landing/images/image_1758897836773.jpg
# Moved: temporal-landing/image_168.jpg -> persistent-landing/images/image_1758897836798.jpg
# Moved: temporal-landing/image_169.jpg -> persistent-landing/images/image_1758897836824.jpg
# Moved: temporal-landing/image_17.jpg -> persistent-landing/images/image_1758897836846.jpg
# Moved: temporal-landing/image_170.jpg -> persistent-landing/images/image_1758897836866.jpg
# Moved: temporal-landing/image_171.jpg -> persistent-landing/images/image_1758897836889.jpg
# Moved: temporal-landing/image_172.jpg -> persistent-landing/images/image_1758897836909.jpg
# Moved: temporal-landing/image_173.jpg -> persistent-landing/images/image_1758897836931.jpg
# Moved: temporal-landing/image_174.jpg -> persistent-landing/images/image_1758897836951.jpg
# Moved: temporal-landing/image_175.jpg -> persistent-landing/images/image_1758897836975.jpg
# Moved: temporal-landing/image_176.jpg -> persistent-landing/images/image_1758897837014.jpg
# Moved: temporal-landing/image_177.jpg -> persistent-landing/images/image_1758897837046.jpg
# Moved: temporal-landing/image_178.jpg -> persistent-landing/images/image_1758897837078.jpg
# Moved: temporal-landing/image_179.jpg -> persistent-landing/images/image_1758897837116.jpg
# Moved: temporal-landing/image_18.jpg -> persistent-landing/images/image_1758897837145.jpg
# Moved: temporal-landing/image_180.jpg -> persistent-landing/images/image_1758897837175.jpg
# Moved: temporal-landing/image_181.jpg -> persistent-landing/images/image_1758897837207.jpg
# Moved: temporal-landing/image_182.jpg -> persistent-landing/images/image_1758897837240.jpg
# Moved: temporal-landing/image_183.jpg -> persistent-landing/images/image_1758897837270.jpg
# Moved: temporal-landing/image_184.jpg -> persistent-landing/images/image_1758897837302.jpg
# Moved: temporal-landing/image_185.jpg -> persistent-landing/images/image_1758897837327.jpg
# Moved: temporal-landing/image_186.jpg -> persistent-landing/images/image_1758897837353.jpg
# Moved: temporal-landing/image_187.jpg -> persistent-landing/images/image_1758897837378.jpg
# Moved: temporal-landing/image_188.jpg -> persistent-landing/images/image_1758897837401.jpg
# Moved: temporal-landing/image_189.jpg -> persistent-landing/images/image_1758897837427.jpg
# Moved: temporal-landing/image_19.jpg -> persistent-landing/images/image_1758897837455.jpg
# Moved: temporal-landing/image_190.jpg -> persistent-landing/images/image_1758897837481.jpg
# Moved: temporal-landing/image_191.jpg -> persistent-landing/images/image_1758897837505.jpg
# Moved: temporal-landing/image_192.jpg -> persistent-landing/images/image_1758897837537.jpg
# Moved: temporal-landing/image_193.jpg -> persistent-landing/images/image_1758897837577.jpg
# Moved: temporal-landing/image_194.jpg -> persistent-landing/images/image_1758897837603.jpg
# Moved: temporal-landing/image_195.jpg -> persistent-landing/images/image_1758897837636.jpg
# Moved: temporal-landing/image_196.jpg -> persistent-landing/images/image_1758897837664.jpg
# Moved: temporal-landing/image_197.jpg -> persistent-landing/images/image_1758897837692.jpg
# Moved: temporal-landing/image_198.jpg -> persistent-landing/images/image_1758897837719.jpg
# Moved: temporal-landing/image_199.jpg -> persistent-landing/images/image_1758897837743.jpg
# Moved: temporal-landing/image_2.jpg -> persistent-landing/images/image_1758897837769.jpg
# Moved: temporal-landing/image_20.jpg -> persistent-landing/images/image_1758897837791.jpg
# Moved: temporal-landing/image_200.jpg -> persistent-landing/images/image_1758897837814.jpg
# Moved: temporal-landing/image_21.jpg -> persistent-landing/images/image_1758897837843.jpg
# Moved: temporal-landing/image_22.jpg -> persistent-landing/images/image_1758897837865.jpg
# Moved: temporal-landing/image_23.jpg -> persistent-landing/images/image_1758897837889.jpg
# Moved: temporal-landing/image_24.jpg -> persistent-landing/images/image_1758897837914.jpg
# Moved: temporal-landing/image_25.jpg -> persistent-landing/images/image_1758897837939.jpg
# Moved: temporal-landing/image_26.jpg -> persistent-landing/images/image_1758897837964.jpg
# Moved: temporal-landing/image_27.jpg -> persistent-landing/images/image_1758897837990.jpg
# Moved: temporal-landing/image_28.jpg -> persistent-landing/images/image_1758897838014.jpg
# Moved: temporal-landing/image_29.jpg -> persistent-landing/images/image_1758897838043.jpg
# Moved: temporal-landing/image_3.jpg -> persistent-landing/images/image_1758897838064.jpg
# Moved: temporal-landing/image_30.jpg -> persistent-landing/images/image_1758897838089.jpg
# Moved: temporal-landing/image_31.jpg -> persistent-landing/images/image_1758897838115.jpg
# Moved: temporal-landing/image_32.jpg -> persistent-landing/images/image_1758897838143.jpg
# Moved: temporal-landing/image_33.jpg -> persistent-landing/images/image_1758897838167.jpg
# Moved: temporal-landing/image_34.jpg -> persistent-landing/images/image_1758897838190.jpg
# Moved: temporal-landing/image_35.jpg -> persistent-landing/images/image_1758897838214.jpg
# Moved: temporal-landing/image_36.jpg -> persistent-landing/images/image_1758897838275.jpg
# Moved: temporal-landing/image_37.jpg -> persistent-landing/images/image_1758897838296.jpg
# Moved: temporal-landing/image_38.jpg -> persistent-landing/images/image_1758897838320.jpg
# Moved: temporal-landing/image_39.jpg -> persistent-landing/images/image_1758897838346.jpg
# Moved: temporal-landing/image_4.jpg -> persistent-landing/images/image_1758897838370.jpg
# Moved: temporal-landing/image_40.jpg -> persistent-landing/images/image_1758897838393.jpg
# Moved: temporal-landing/image_41.jpg -> persistent-landing/images/image_1758897838419.jpg
# Moved: temporal-landing/image_42.jpg -> persistent-landing/images/image_1758897838488.jpg
# Moved: temporal-landing/image_43.jpg -> persistent-landing/images/image_1758897838516.jpg
# Moved: temporal-landing/image_44.jpg -> persistent-landing/images/image_1758897838541.jpg
# Moved: temporal-landing/image_45.jpg -> persistent-landing/images/image_1758897838563.jpg
# Moved: temporal-landing/image_46.jpg -> persistent-landing/images/image_1758897838587.jpg
# Moved: temporal-landing/image_47.jpg -> persistent-landing/images/image_1758897838612.jpg
# Moved: temporal-landing/image_48.jpg -> persistent-landing/images/image_1758897838636.jpg
# Moved: temporal-landing/image_49.jpg -> persistent-landing/images/image_1758897838660.jpg
# Moved: temporal-landing/image_5.jpg -> persistent-landing/images/image_1758897838686.jpg
# Moved: temporal-landing/image_50.jpg -> persistent-landing/images/image_1758897838718.jpg
# Moved: temporal-landing/image_51.jpg -> persistent-landing/images/image_1758897838740.jpg
# Moved: temporal-landing/image_52.jpg -> persistent-landing/images/image_1758897838768.jpg
# Moved: temporal-landing/image_53.jpg -> persistent-landing/images/image_1758897838793.jpg
# Moved: temporal-landing/image_54.jpg -> persistent-landing/images/image_1758897838817.jpg
# Moved: temporal-landing/image_55.jpg -> persistent-landing/images/image_1758897838846.jpg
# Moved: temporal-landing/image_56.jpg -> persistent-landing/images/image_1758897838871.jpg
# Moved: temporal-landing/image_57.jpg -> persistent-landing/images/image_1758897838899.jpg
# Moved: temporal-landing/image_58.jpg -> persistent-landing/images/image_1758897838922.jpg
# Moved: temporal-landing/image_59.jpg -> persistent-landing/images/image_1758897838948.jpg
# Moved: temporal-landing/image_6.jpg -> persistent-landing/images/image_1758897838974.jpg
# Moved: temporal-landing/image_60.jpg -> persistent-landing/images/image_1758897839000.jpg
# Moved: temporal-landing/image_61.jpg -> persistent-landing/images/image_1758897839070.jpg
# Moved: temporal-landing/image_62.jpg -> persistent-landing/images/image_1758897839104.jpg
# Moved: temporal-landing/image_63.jpg -> persistent-landing/images/image_1758897839132.jpg
# Moved: temporal-landing/image_64.jpg -> persistent-landing/images/image_1758897839157.jpg
# Moved: temporal-landing/image_65.jpg -> persistent-landing/images/image_1758897839185.jpg
# Moved: temporal-landing/image_66.jpg -> persistent-landing/images/image_1758897839212.jpg
# Moved: temporal-landing/image_67.jpg -> persistent-landing/images/image_1758897839239.jpg
# Moved: temporal-landing/image_68.jpg -> persistent-landing/images/image_1758897839266.jpg
# Moved: temporal-landing/image_69.jpg -> persistent-landing/images/image_1758897839290.jpg
# Moved: temporal-landing/image_7.jpg -> persistent-landing/images/image_1758897839315.jpg
# Moved: temporal-landing/image_70.jpg -> persistent-landing/images/image_1758897839338.jpg
# Moved: temporal-landing/image_71.jpg -> persistent-landing/images/image_1758897839367.jpg
# Moved: temporal-landing/image_72.jpg -> persistent-landing/images/image_1758897839394.jpg
# Moved: temporal-landing/image_73.jpg -> persistent-landing/images/image_1758897839418.jpg
# Moved: temporal-landing/image_74.jpg -> persistent-landing/images/image_1758897839443.jpg
# Moved: temporal-landing/image_75.jpg -> persistent-landing/images/image_1758897839470.jpg
# Moved: temporal-landing/image_76.jpg -> persistent-landing/images/image_1758897839537.jpg
# Moved: temporal-landing/image_77.jpg -> persistent-landing/images/image_1758897839572.jpg
# Moved: temporal-landing/image_78.jpg -> persistent-landing/images/image_1758897839603.jpg
# Moved: temporal-landing/image_79.jpg -> persistent-landing/images/image_1758897839629.jpg
# Moved: temporal-landing/image_8.jpg -> persistent-landing/images/image_1758897839654.jpg
# Moved: temporal-landing/image_80.jpg -> persistent-landing/images/image_1758897839681.jpg
# Moved: temporal-landing/image_81.jpg -> persistent-landing/images/image_1758897839706.jpg
# Moved: temporal-landing/image_82.jpg -> persistent-landing/images/image_1758897839732.jpg
# Moved: temporal-landing/image_83.jpg -> persistent-landing/images/image_1758897839754.jpg
# Moved: temporal-landing/image_84.jpg -> persistent-landing/images/image_1758897839778.jpg
# Moved: temporal-landing/image_85.jpg -> persistent-landing/images/image_1758897839796.jpg
# Moved: temporal-landing/image_86.jpg -> persistent-landing/images/image_1758897839817.jpg
# Moved: temporal-landing/image_87.jpg -> persistent-landing/images/image_1758897839855.jpg
# Moved: temporal-landing/image_88.jpg -> persistent-landing/images/image_1758897839883.jpg
# Moved: temporal-landing/image_89.jpg -> persistent-landing/images/image_1758897839914.jpg
# Moved: temporal-landing/image_9.jpg -> persistent-landing/images/image_1758897839937.jpg
# Moved: temporal-landing/image_90.jpg -> persistent-landing/images/image_1758897839960.jpg
# Moved: temporal-landing/image_91.jpg -> persistent-landing/images/image_1758897839982.jpg
# Moved: temporal-landing/image_92.jpg -> persistent-landing/images/image_1758897840046.jpg
# Moved: temporal-landing/image_93.jpg -> persistent-landing/images/image_1758897840066.jpg
# Moved: temporal-landing/image_94.jpg -> persistent-landing/images/image_1758897840089.jpg
# Moved: temporal-landing/image_95.jpg -> persistent-landing/images/image_1758897840113.jpg
# Moved: temporal-landing/image_96.jpg -> persistent-landing/images/image_1758897840136.jpg
# Moved: temporal-landing/image_97.jpg -> persistent-landing/images/image_1758897840156.jpg
# Moved: temporal-landing/image_98.jpg -> persistent-landing/images/image_1758897840181.jpg
# Moved: temporal-landing/image_99.jpg -> persistent-landing/images/image_1758897840211.jpg
# Moved: temporal-landing/text_1.txt -> persistent-landing/texts/text_1758897840237.txt
# Moved: temporal-landing/text_10.txt -> persistent-landing/texts/text_1758897840260.txt
# Moved: temporal-landing/text_100.txt -> persistent-landing/texts/text_1758897840286.txt
# Moved: temporal-landing/text_101.txt -> persistent-landing/texts/text_1758897840310.txt
# Moved: temporal-landing/text_102.txt -> persistent-landing/texts/text_1758897840332.txt
# Moved: temporal-landing/text_103.txt -> persistent-landing/texts/text_1758897840359.txt
# Moved: temporal-landing/text_104.txt -> persistent-landing/texts/text_1758897840426.txt
# Moved: temporal-landing/text_105.txt -> persistent-landing/texts/text_1758897840457.txt
# Moved: temporal-landing/text_106.txt -> persistent-landing/texts/text_1758897840485.txt
# Moved: temporal-landing/text_107.txt -> persistent-landing/texts/text_1758897840513.txt
# Moved: temporal-landing/text_108.txt -> persistent-landing/texts/text_1758897840540.txt
# Moved: temporal-landing/text_109.txt -> persistent-landing/texts/text_1758897840565.txt
# Moved: temporal-landing/text_11.txt -> persistent-landing/texts/text_1758897840590.txt
# Moved: temporal-landing/text_110.txt -> persistent-landing/texts/text_1758897840615.txt
# Moved: temporal-landing/text_111.txt -> persistent-landing/texts/text_1758897840640.txt
# Moved: temporal-landing/text_112.txt -> persistent-landing/texts/text_1758897840665.txt
# Moved: temporal-landing/text_113.txt -> persistent-landing/texts/text_1758897840690.txt
# Moved: temporal-landing/text_114.txt -> persistent-landing/texts/text_1758897840715.txt
# Moved: temporal-landing/text_115.txt -> persistent-landing/texts/text_1758897840740.txt
# Moved: temporal-landing/text_116.txt -> persistent-landing/texts/text_1758897840767.txt
# Moved: temporal-landing/text_117.txt -> persistent-landing/texts/text_1758897840793.txt
# Moved: temporal-landing/text_118.txt -> persistent-landing/texts/text_1758897840818.txt
# Moved: temporal-landing/text_119.txt -> persistent-landing/texts/text_1758897840841.txt
# Moved: temporal-landing/text_12.txt -> persistent-landing/texts/text_1758897840865.txt
# Moved: temporal-landing/text_120.txt -> persistent-landing/texts/text_1758897840891.txt
# Moved: temporal-landing/text_121.txt -> persistent-landing/texts/text_1758897840916.txt
# Moved: temporal-landing/text_122.txt -> persistent-landing/texts/text_1758897840944.txt
# Moved: temporal-landing/text_123.txt -> persistent-landing/texts/text_1758897840971.txt
# Moved: temporal-landing/text_124.txt -> persistent-landing/texts/text_1758897840996.txt
# Moved: temporal-landing/text_125.txt -> persistent-landing/texts/text_1758897841022.txt
# Moved: temporal-landing/text_126.txt -> persistent-landing/texts/text_1758897841047.txt
# Moved: temporal-landing/text_127.txt -> persistent-landing/texts/text_1758897841071.txt
# Moved: temporal-landing/text_128.txt -> persistent-landing/texts/text_1758897841096.txt
# Moved: temporal-landing/text_129.txt -> persistent-landing/texts/text_1758897841121.txt
# Moved: temporal-landing/text_13.txt -> persistent-landing/texts/text_1758897841147.txt
# Moved: temporal-landing/text_130.txt -> persistent-landing/texts/text_1758897841172.txt
# Moved: temporal-landing/text_131.txt -> persistent-landing/texts/text_1758897841197.txt
# Moved: temporal-landing/text_132.txt -> persistent-landing/texts/text_1758897841220.txt
# Moved: temporal-landing/text_133.txt -> persistent-landing/texts/text_1758897841244.txt
# Moved: temporal-landing/text_134.txt -> persistent-landing/texts/text_1758897841273.txt
# Moved: temporal-landing/text_135.txt -> persistent-landing/texts/text_1758897841300.txt
# Moved: temporal-landing/text_136.txt -> persistent-landing/texts/text_1758897841324.txt
# Moved: temporal-landing/text_137.txt -> persistent-landing/texts/text_1758897841346.txt
# Moved: temporal-landing/text_138.txt -> persistent-landing/texts/text_1758897841371.txt
# Moved: temporal-landing/text_139.txt -> persistent-landing/texts/text_1758897841397.txt
# Moved: temporal-landing/text_14.txt -> persistent-landing/texts/text_1758897841422.txt
# Moved: temporal-landing/text_140.txt -> persistent-landing/texts/text_1758897841447.txt
# Moved: temporal-landing/text_141.txt -> persistent-landing/texts/text_1758897841475.txt
# Moved: temporal-landing/text_142.txt -> persistent-landing/texts/text_1758897841503.txt
# Moved: temporal-landing/text_143.txt -> persistent-landing/texts/text_1758897841531.txt
# Moved: temporal-landing/text_144.txt -> persistent-landing/texts/text_1758897841557.txt
# Moved: temporal-landing/text_145.txt -> persistent-landing/texts/text_1758897841583.txt
# Moved: temporal-landing/text_146.txt -> persistent-landing/texts/text_1758897841614.txt
# Moved: temporal-landing/text_147.txt -> persistent-landing/texts/text_1758897841642.txt
# Moved: temporal-landing/text_148.txt -> persistent-landing/texts/text_1758897841666.txt
# Moved: temporal-landing/text_149.txt -> persistent-landing/texts/text_1758897841689.txt
# Moved: temporal-landing/text_15.txt -> persistent-landing/texts/text_1758897841716.txt
# Moved: temporal-landing/text_150.txt -> persistent-landing/texts/text_1758897841743.txt
# Moved: temporal-landing/text_151.txt -> persistent-landing/texts/text_1758897841767.txt
# Moved: temporal-landing/text_152.txt -> persistent-landing/texts/text_1758897841791.txt
# Moved: temporal-landing/text_153.txt -> persistent-landing/texts/text_1758897841816.txt
# Moved: temporal-landing/text_154.txt -> persistent-landing/texts/text_1758897841844.txt
# Moved: temporal-landing/text_155.txt -> persistent-landing/texts/text_1758897841869.txt
# Moved: temporal-landing/text_156.txt -> persistent-landing/texts/text_1758897841896.txt
# Moved: temporal-landing/text_157.txt -> persistent-landing/texts/text_1758897841923.txt
# Moved: temporal-landing/text_158.txt -> persistent-landing/texts/text_1758897841947.txt
# Moved: temporal-landing/text_159.txt -> persistent-landing/texts/text_1758897841971.txt
# Moved: temporal-landing/text_16.txt -> persistent-landing/texts/text_1758897841994.txt
# Moved: temporal-landing/text_160.txt -> persistent-landing/texts/text_1758897842018.txt
# Moved: temporal-landing/text_161.txt -> persistent-landing/texts/text_1758897842041.txt
# Moved: temporal-landing/text_162.txt -> persistent-landing/texts/text_1758897842064.txt
# Moved: temporal-landing/text_163.txt -> persistent-landing/texts/text_1758897842126.txt
# Moved: temporal-landing/text_164.txt -> persistent-landing/texts/text_1758897842159.txt
# Moved: temporal-landing/text_165.txt -> persistent-landing/texts/text_1758897842184.txt
# Moved: temporal-landing/text_166.txt -> persistent-landing/texts/text_1758897842209.txt
# Moved: temporal-landing/text_167.txt -> persistent-landing/texts/text_1758897842232.txt
# Moved: temporal-landing/text_168.txt -> persistent-landing/texts/text_1758897842253.txt
# Moved: temporal-landing/text_169.txt -> persistent-landing/texts/text_1758897842277.txt
# Moved: temporal-landing/text_17.txt -> persistent-landing/texts/text_1758897842300.txt
# Moved: temporal-landing/text_170.txt -> persistent-landing/texts/text_1758897842322.txt
# Moved: temporal-landing/text_171.txt -> persistent-landing/texts/text_1758897842343.txt
# Moved: temporal-landing/text_172.txt -> persistent-landing/texts/text_1758897842365.txt
# Moved: temporal-landing/text_173.txt -> persistent-landing/texts/text_1758897842385.txt
# Moved: temporal-landing/text_174.txt -> persistent-landing/texts/text_1758897842405.txt
# Moved: temporal-landing/text_175.txt -> persistent-landing/texts/text_1758897842427.txt
# Moved: temporal-landing/text_176.txt -> persistent-landing/texts/text_1758897842453.txt
# Moved: temporal-landing/text_177.txt -> persistent-landing/texts/text_1758897842482.txt
# Moved: temporal-landing/text_178.txt -> persistent-landing/texts/text_1758897842503.txt
# Moved: temporal-landing/text_179.txt -> persistent-landing/texts/text_1758897842525.txt
# Moved: temporal-landing/text_18.txt -> persistent-landing/texts/text_1758897842547.txt
# Moved: temporal-landing/text_180.txt -> persistent-landing/texts/text_1758897842569.txt
# Moved: temporal-landing/text_181.txt -> persistent-landing/texts/text_1758897842593.txt
# Moved: temporal-landing/text_182.txt -> persistent-landing/texts/text_1758897842615.txt
# Moved: temporal-landing/text_183.txt -> persistent-landing/texts/text_1758897842636.txt
# Moved: temporal-landing/text_184.txt -> persistent-landing/texts/text_1758897842655.txt
# Moved: temporal-landing/text_185.txt -> persistent-landing/texts/text_1758897842677.txt
# Moved: temporal-landing/text_186.txt -> persistent-landing/texts/text_1758897842698.txt
# Moved: temporal-landing/text_187.txt -> persistent-landing/texts/text_1758897842719.txt
# Moved: temporal-landing/text_188.txt -> persistent-landing/texts/text_1758897842737.txt
# Moved: temporal-landing/text_189.txt -> persistent-landing/texts/text_1758897842760.txt
# Moved: temporal-landing/text_19.txt -> persistent-landing/texts/text_1758897842785.txt
# Moved: temporal-landing/text_190.txt -> persistent-landing/texts/text_1758897842818.txt
# Moved: temporal-landing/text_191.txt -> persistent-landing/texts/text_1758897842844.txt
# Moved: temporal-landing/text_192.txt -> persistent-landing/texts/text_1758897842868.txt
# Moved: temporal-landing/text_193.txt -> persistent-landing/texts/text_1758897842935.txt
# Moved: temporal-landing/text_194.txt -> persistent-landing/texts/text_1758897842969.txt
# Moved: temporal-landing/text_195.txt -> persistent-landing/texts/text_1758897842996.txt
# Moved: temporal-landing/text_196.txt -> persistent-landing/texts/text_1758897843023.txt
# Moved: temporal-landing/text_197.txt -> persistent-landing/texts/text_1758897843058.txt
# Moved: temporal-landing/text_198.txt -> persistent-landing/texts/text_1758897843095.txt
# Moved: temporal-landing/text_199.txt -> persistent-landing/texts/text_1758897843133.txt
# Moved: temporal-landing/text_2.txt -> persistent-landing/texts/text_1758897843169.txt
# Moved: temporal-landing/text_20.txt -> persistent-landing/texts/text_1758897843201.txt
# Moved: temporal-landing/text_200.txt -> persistent-landing/texts/text_1758897843239.txt
# Moved: temporal-landing/text_21.txt -> persistent-landing/texts/text_1758897843269.txt
# Moved: temporal-landing/text_22.txt -> persistent-landing/texts/text_1758897843292.txt
# Moved: temporal-landing/text_23.txt -> persistent-landing/texts/text_1758897843313.txt
# Moved: temporal-landing/text_24.txt -> persistent-landing/texts/text_1758897843337.txt
# Moved: temporal-landing/text_25.txt -> persistent-landing/texts/text_1758897843363.txt
# Moved: temporal-landing/text_26.txt -> persistent-landing/texts/text_1758897843386.txt
# Moved: temporal-landing/text_27.txt -> persistent-landing/texts/text_1758897843409.txt
# Moved: temporal-landing/text_28.txt -> persistent-landing/texts/text_1758897843433.txt
# Moved: temporal-landing/text_29.txt -> persistent-landing/texts/text_1758897843456.txt
# Moved: temporal-landing/text_3.txt -> persistent-landing/texts/text_1758897843483.txt
# Moved: temporal-landing/text_30.txt -> persistent-landing/texts/text_1758897843511.txt
# Moved: temporal-landing/text_31.txt -> persistent-landing/texts/text_1758897843531.txt
# Moved: temporal-landing/text_32.txt -> persistent-landing/texts/text_1758897843551.txt
# Moved: temporal-landing/text_33.txt -> persistent-landing/texts/text_1758897843575.txt
# Moved: temporal-landing/text_34.txt -> persistent-landing/texts/text_1758897843599.txt
# Moved: temporal-landing/text_35.txt -> persistent-landing/texts/text_1758897843624.txt
# Moved: temporal-landing/text_36.txt -> persistent-landing/texts/text_1758897843650.txt
# Moved: temporal-landing/text_37.txt -> persistent-landing/texts/text_1758897843673.txt
# Moved: temporal-landing/text_38.txt -> persistent-landing/texts/text_1758897843696.txt
# Moved: temporal-landing/text_39.txt -> persistent-landing/texts/text_1758897843720.txt
# Moved: temporal-landing/text_4.txt -> persistent-landing/texts/text_1758897843746.txt
# Moved: temporal-landing/text_40.txt -> persistent-landing/texts/text_1758897843767.txt
# Moved: temporal-landing/text_41.txt -> persistent-landing/texts/text_1758897843794.txt
# Moved: temporal-landing/text_42.txt -> persistent-landing/texts/text_1758897843817.txt
# Moved: temporal-landing/text_43.txt -> persistent-landing/texts/text_1758897843839.txt
# Moved: temporal-landing/text_44.txt -> persistent-landing/texts/text_1758897843862.txt
# Moved: temporal-landing/text_45.txt -> persistent-landing/texts/text_1758897843887.txt
# Moved: temporal-landing/text_46.txt -> persistent-landing/texts/text_1758897843936.txt
# Moved: temporal-landing/text_47.txt -> persistent-landing/texts/text_1758897843963.txt
# Moved: temporal-landing/text_48.txt -> persistent-landing/texts/text_1758897843990.txt
# Moved: temporal-landing/text_49.txt -> persistent-landing/texts/text_1758897844018.txt
# Moved: temporal-landing/text_5.txt -> persistent-landing/texts/text_1758897844050.txt
# Moved: temporal-landing/text_50.txt -> persistent-landing/texts/text_1758897844082.txt
# Moved: temporal-landing/text_51.txt -> persistent-landing/texts/text_1758897844115.txt
# Moved: temporal-landing/text_52.txt -> persistent-landing/texts/text_1758897844148.txt
# Moved: temporal-landing/text_53.txt -> persistent-landing/texts/text_1758897844177.txt
# Moved: temporal-landing/text_54.txt -> persistent-landing/texts/text_1758897844199.txt
# Moved: temporal-landing/text_55.txt -> persistent-landing/texts/text_1758897844230.txt
# Moved: temporal-landing/text_56.txt -> persistent-landing/texts/text_1758897844254.txt
# Moved: temporal-landing/text_57.txt -> persistent-landing/texts/text_1758897844284.txt
# Moved: temporal-landing/text_58.txt -> persistent-landing/texts/text_1758897844313.txt
# Moved: temporal-landing/text_59.txt -> persistent-landing/texts/text_1758897844339.txt
# Moved: temporal-landing/text_6.txt -> persistent-landing/texts/text_1758897844373.txt
# Moved: temporal-landing/text_60.txt -> persistent-landing/texts/text_1758897844403.txt
# Moved: temporal-landing/text_61.txt -> persistent-landing/texts/text_1758897844433.txt
# Moved: temporal-landing/text_62.txt -> persistent-landing/texts/text_1758897844460.txt
# Moved: temporal-landing/text_63.txt -> persistent-landing/texts/text_1758897844489.txt
# Moved: temporal-landing/text_64.txt -> persistent-landing/texts/text_1758897844516.txt
# Moved: temporal-landing/text_65.txt -> persistent-landing/texts/text_1758897844541.txt
# Moved: temporal-landing/text_66.txt -> persistent-landing/texts/text_1758897844570.txt
# Moved: temporal-landing/text_67.txt -> persistent-landing/texts/text_1758897844600.txt
# Moved: temporal-landing/text_68.txt -> persistent-landing/texts/text_1758897844628.txt
# Moved: temporal-landing/text_69.txt -> persistent-landing/texts/text_1758897844658.txt
# Moved: temporal-landing/text_7.txt -> persistent-landing/texts/text_1758897844681.txt
# Moved: temporal-landing/text_70.txt -> persistent-landing/texts/text_1758897844709.txt
# Moved: temporal-landing/text_71.txt -> persistent-landing/texts/text_1758897844751.txt
# Moved: temporal-landing/text_72.txt -> persistent-landing/texts/text_1758897844780.txt
# Moved: temporal-landing/text_73.txt -> persistent-landing/texts/text_1758897844805.txt
# Moved: temporal-landing/text_74.txt -> persistent-landing/texts/text_1758897844829.txt
# Moved: temporal-landing/text_75.txt -> persistent-landing/texts/text_1758897844853.txt
# Moved: temporal-landing/text_76.txt -> persistent-landing/texts/text_1758897844879.txt
# Moved: temporal-landing/text_77.txt -> persistent-landing/texts/text_1758897844905.txt
# Moved: temporal-landing/text_78.txt -> persistent-landing/texts/text_1758897844930.txt
# Moved: temporal-landing/text_79.txt -> persistent-landing/texts/text_1758897844959.txt
# Moved: temporal-landing/text_8.txt -> persistent-landing/texts/text_1758897844988.txt
# Moved: temporal-landing/text_80.txt -> persistent-landing/texts/text_1758897845013.txt
# Moved: temporal-landing/text_81.txt -> persistent-landing/texts/text_1758897845042.txt
# Moved: temporal-landing/text_82.txt -> persistent-landing/texts/text_1758897845063.txt
# Moved: temporal-landing/text_83.txt -> persistent-landing/texts/text_1758897845092.txt
# Moved: temporal-landing/text_84.txt -> persistent-landing/texts/text_1758897845116.txt
# Moved: temporal-landing/text_85.txt -> persistent-landing/texts/text_1758897845140.txt
# Moved: temporal-landing/text_86.txt -> persistent-landing/texts/text_1758897845165.txt
# Moved: temporal-landing/text_87.txt -> persistent-landing/texts/text_1758897845188.txt
# Moved: temporal-landing/text_88.txt -> persistent-landing/texts/text_1758897845204.txt
# Moved: temporal-landing/text_89.txt -> persistent-landing/texts/text_1758897845226.txt
# Moved: temporal-landing/text_9.txt -> persistent-landing/texts/text_1758897845293.txt
# Moved: temporal-landing/text_90.txt -> persistent-landing/texts/text_1758897845327.txt
# Moved: temporal-landing/text_91.txt -> persistent-landing/texts/text_1758897845354.txt
# Moved: temporal-landing/text_92.txt -> persistent-landing/texts/text_1758897845380.txt
# Moved: temporal-landing/text_93.txt -> persistent-landing/texts/text_1758897845407.txt
# Moved: temporal-landing/text_94.txt -> persistent-landing/texts/text_1758897845433.txt
# Moved: temporal-landing/text_95.txt -> persistent-landing/texts/text_1758897845458.txt
# Moved: temporal-landing/text_96.txt -> persistent-landing/texts/text_1758897845481.txt
# Moved: temporal-landing/text_97.txt -> persistent-landing/texts/text_1758897845505.txt
# Moved: temporal-landing/text_98.txt -> persistent-landing/texts/text_1758897845531.txt
# Moved: temporal-landing/text_99.txt -> persistent-landing/texts/text_1758897845559.txt
# Moved: temporal-landing/video_1.mp4 -> persistent-landing/videos/video_1758897845581.mp4
# Moved: temporal-landing/video_2.mp4 -> persistent-landing/videos/video_1758897845673.mp4
# Moved: temporal-landing/video_3.mp4 -> persistent-landing/videos/video_1758897845738.mp4
# Moved: temporal-landing/video_4.mp4 -> persistent-landing/videos/video_1758897845798.mp4
# Moved: temporal-landing/video_5.mp4 -> persistent-landing/videos/video_1758897845868.mp4
