# %% [markdown]
# ## Persistent Landing

# %%
# Importing useful dependencies
import time
import boto3

# %%
# Setup S3 client for MinIO (MinIO implements Amazon S3 API)
s3 = boto3.client(
    "s3",
    endpoint_url="http://127.0.0.1:9000", # MinIO API endpoint
    aws_access_key_id="minioadmin", # User name
    aws_secret_access_key="minioadmin", # Password
)

# %%
# Create three sub-buckets inside persistent-landing, one per format
s3.put_object(Bucket="landing-zone", Key="persistent-landing/texts/") # Sub-bucket Text
s3.put_object(Bucket="landing-zone", Key="persistent-landing/images/") # Sub-bucket Image
s3.put_object(Bucket="landing-zone", Key="persistent-landing/videos/") # Sub-bucket Video
# Out:
# {'ResponseMetadata': {'RequestId': '18696AEF36BED5F7',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '0',
#    'etag': '"d41d8cd98f00b204e9800998ecf8427e"',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-checksum-crc32': 'AAAAAA==',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '18696AEF36BED5F7',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '1850',
#    'x-ratelimit-remaining': '1850',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Sun, 28 Sep 2025 10:18:25 GMT'},
#   'RetryAttempts': 0},
#  'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#  'ChecksumCRC32': 'AAAAAA==',
#  'ChecksumType': 'FULL_OBJECT'}

# %%
# This function checks an object's ContentType (via head_object) and classifies it as "texts", "images", or "videos"
# based on whether the type starts with text/, image/, or video/.
def classify_object_by_head(client, bucket, key):
    # ask S3 for ContentType
    head = client.head_object(Bucket=bucket, Key=key)
    ct = head.get("ContentType", "")
    if ct.startswith("text/"):
        return "texts"
    elif ct.startswith("image/"):
        return "images"
    elif ct.startswith("video/"):
        return "videos"

# %%
# This function moves all files from the source_prefix folder to the dest_prefix folder,
# classifying each file as text, image, or video (based on ContentType), renaming it with a timestamped filename (ingestion time),
# copying it to the appropriate subfolder (texts/, images/, videos/), and then deleting the original files in the source_prefix.
def move_files(client, bucket, source_prefix="temporal-landing/", dest_prefix="persistent-landing/"):
    
    paginator = client.get_paginator("list_objects_v2") # It returns objects in pages and not all at once.

    for page in paginator.paginate(Bucket=bucket, Prefix=source_prefix):
        for obj in page.get("Contents", []):

            if obj['Size'] == 0:
                continue
            
            src_key = obj["Key"]

            # classify
            category = classify_object_by_head(client, bucket, src_key)

            # get file extension
            ext = src_key.split('.')[-1].split('?')[0]

            # new filename = timestamp + original extension
            ts = int(time.time() * 1000)  # milliseconds
            new_filename = f"{category[0:-1]}_{ts}.{ext}"

            # build destination key
            dest_key = f"{dest_prefix}{category}/{new_filename}"

            # copy then delete
            client.copy_object(Bucket=bucket, CopySource={"Bucket": bucket, "Key": src_key}, Key=dest_key)
            client.delete_object(Bucket=bucket, Key=src_key)

            print(f"Moved: {src_key} -> {dest_key}")

# %%
# Moving files from Temporal Landing to Persistent Landing and removing temporal files
move_files(s3, "landing-zone", "temporal-landing/", "persistent-landing/")
# Out:
# Moved: temporal-landing/image_1.jpg -> persistent-landing/images/image_1759054705485.jpg
# Moved: temporal-landing/image_10.jpg -> persistent-landing/images/image_1759054705506.jpg
# Moved: temporal-landing/image_100.jpg -> persistent-landing/images/image_1759054705517.jpg
# Moved: temporal-landing/image_101.jpg -> persistent-landing/images/image_1759054705529.jpg
# Moved: temporal-landing/image_102.jpg -> persistent-landing/images/image_1759054705544.jpg
# Moved: temporal-landing/image_103.jpg -> persistent-landing/images/image_1759054705557.jpg
# Moved: temporal-landing/image_104.jpg -> persistent-landing/images/image_1759054705573.jpg
# Moved: temporal-landing/image_105.jpg -> persistent-landing/images/image_1759054705591.jpg
# Moved: temporal-landing/image_106.jpg -> persistent-landing/images/image_1759054705604.jpg
# Moved: temporal-landing/image_107.jpg -> persistent-landing/images/image_1759054705616.jpg
# Moved: temporal-landing/image_108.jpg -> persistent-landing/images/image_1759054705629.jpg
# Moved: temporal-landing/image_109.jpg -> persistent-landing/images/image_1759054705647.jpg
# Moved: temporal-landing/image_11.jpg -> persistent-landing/images/image_1759054705666.jpg
# Moved: temporal-landing/image_110.jpg -> persistent-landing/images/image_1759054705683.jpg
# Moved: temporal-landing/image_111.jpg -> persistent-landing/images/image_1759054705703.jpg
# Moved: temporal-landing/image_112.jpg -> persistent-landing/images/image_1759054705717.jpg
# Moved: temporal-landing/image_113.jpg -> persistent-landing/images/image_1759054705732.jpg
# Moved: temporal-landing/image_114.jpg -> persistent-landing/images/image_1759054705745.jpg
# Moved: temporal-landing/image_115.jpg -> persistent-landing/images/image_1759054705757.jpg
# Moved: temporal-landing/image_116.jpg -> persistent-landing/images/image_1759054705768.jpg
# Moved: temporal-landing/image_117.jpg -> persistent-landing/images/image_1759054705778.jpg
# Moved: temporal-landing/image_118.jpg -> persistent-landing/images/image_1759054705789.jpg
# Moved: temporal-landing/image_119.jpg -> persistent-landing/images/image_1759054705803.jpg
# Moved: temporal-landing/image_12.jpg -> persistent-landing/images/image_1759054705816.jpg
# Moved: temporal-landing/image_120.jpg -> persistent-landing/images/image_1759054705826.jpg
# Moved: temporal-landing/image_121.jpg -> persistent-landing/images/image_1759054705838.jpg
# Moved: temporal-landing/image_122.jpg -> persistent-landing/images/image_1759054705852.jpg
# Moved: temporal-landing/image_123.jpg -> persistent-landing/images/image_1759054705868.jpg
# Moved: temporal-landing/image_124.jpg -> persistent-landing/images/image_1759054705880.jpg
# Moved: temporal-landing/image_125.jpg -> persistent-landing/images/image_1759054705893.jpg
# Moved: temporal-landing/image_126.jpg -> persistent-landing/images/image_1759054705907.jpg
# Moved: temporal-landing/image_127.jpg -> persistent-landing/images/image_1759054705921.jpg
# Moved: temporal-landing/image_128.jpg -> persistent-landing/images/image_1759054705934.jpg
# Moved: temporal-landing/image_129.jpg -> persistent-landing/images/image_1759054705955.jpg
# Moved: temporal-landing/image_13.jpg -> persistent-landing/images/image_1759054705970.jpg
# Moved: temporal-landing/image_130.jpg -> persistent-landing/images/image_1759054705981.jpg
# Moved: temporal-landing/image_131.jpg -> persistent-landing/images/image_1759054705996.jpg
# Moved: temporal-landing/image_132.jpg -> persistent-landing/images/image_1759054706028.jpg
# Moved: temporal-landing/image_133.jpg -> persistent-landing/images/image_1759054706043.jpg
# Moved: temporal-landing/image_134.jpg -> persistent-landing/images/image_1759054706062.jpg
# Moved: temporal-landing/image_135.jpg -> persistent-landing/images/image_1759054706075.jpg
# Moved: temporal-landing/image_136.jpg -> persistent-landing/images/image_1759054706090.jpg
# Moved: temporal-landing/image_137.jpg -> persistent-landing/images/image_1759054706105.jpg
# Moved: temporal-landing/image_138.jpg -> persistent-landing/images/image_1759054706126.jpg
# Moved: temporal-landing/image_139.jpg -> persistent-landing/images/image_1759054706142.jpg
# Moved: temporal-landing/image_14.jpg -> persistent-landing/images/image_1759054706158.jpg
# Moved: temporal-landing/image_140.jpg -> persistent-landing/images/image_1759054706173.jpg
# Moved: temporal-landing/image_141.jpg -> persistent-landing/images/image_1759054706212.jpg
# Moved: temporal-landing/image_142.jpg -> persistent-landing/images/image_1759054706223.jpg
# Moved: temporal-landing/image_143.jpg -> persistent-landing/images/image_1759054706236.jpg
# Moved: temporal-landing/image_144.jpg -> persistent-landing/images/image_1759054706249.jpg
# Moved: temporal-landing/image_145.jpg -> persistent-landing/images/image_1759054706263.jpg
# Moved: temporal-landing/image_146.jpg -> persistent-landing/images/image_1759054706290.jpg
# Moved: temporal-landing/image_147.jpg -> persistent-landing/images/image_1759054706304.jpg
# Moved: temporal-landing/image_148.jpg -> persistent-landing/images/image_1759054706316.jpg
# Moved: temporal-landing/image_149.jpg -> persistent-landing/images/image_1759054706329.jpg
# Moved: temporal-landing/image_15.jpg -> persistent-landing/images/image_1759054706343.jpg
# Moved: temporal-landing/image_150.jpg -> persistent-landing/images/image_1759054706354.jpg
# Moved: temporal-landing/image_151.jpg -> persistent-landing/images/image_1759054706367.jpg
# Moved: temporal-landing/image_152.jpg -> persistent-landing/images/image_1759054706384.jpg
# Moved: temporal-landing/image_153.jpg -> persistent-landing/images/image_1759054706396.jpg
# Moved: temporal-landing/image_154.jpg -> persistent-landing/images/image_1759054706407.jpg
# Moved: temporal-landing/image_155.jpg -> persistent-landing/images/image_1759054706419.jpg
# Moved: temporal-landing/image_156.jpg -> persistent-landing/images/image_1759054706431.jpg
# Moved: temporal-landing/image_157.jpg -> persistent-landing/images/image_1759054706441.jpg
# Moved: temporal-landing/image_158.jpg -> persistent-landing/images/image_1759054706462.jpg
# Moved: temporal-landing/image_159.jpg -> persistent-landing/images/image_1759054706480.jpg
# Moved: temporal-landing/image_16.jpg -> persistent-landing/images/image_1759054706495.jpg
# Moved: temporal-landing/image_160.jpg -> persistent-landing/images/image_1759054706506.jpg
# Moved: temporal-landing/image_161.jpg -> persistent-landing/images/image_1759054706519.jpg
# Moved: temporal-landing/image_162.jpg -> persistent-landing/images/image_1759054706531.jpg
# Moved: temporal-landing/image_163.jpg -> persistent-landing/images/image_1759054706568.jpg
# Moved: temporal-landing/image_164.jpg -> persistent-landing/images/image_1759054706583.jpg
# Moved: temporal-landing/image_165.jpg -> persistent-landing/images/image_1759054706596.jpg
# Moved: temporal-landing/image_166.jpg -> persistent-landing/images/image_1759054706606.jpg
# Moved: temporal-landing/image_167.jpg -> persistent-landing/images/image_1759054706618.jpg
# Moved: temporal-landing/image_168.jpg -> persistent-landing/images/image_1759054706631.jpg
# Moved: temporal-landing/image_169.jpg -> persistent-landing/images/image_1759054706641.jpg
# Moved: temporal-landing/image_17.jpg -> persistent-landing/images/image_1759054706653.jpg
# Moved: temporal-landing/image_170.jpg -> persistent-landing/images/image_1759054706663.jpg
# Moved: temporal-landing/image_171.jpg -> persistent-landing/images/image_1759054706678.jpg
# Moved: temporal-landing/image_172.jpg -> persistent-landing/images/image_1759054706691.jpg
# Moved: temporal-landing/image_173.jpg -> persistent-landing/images/image_1759054706704.jpg
# Moved: temporal-landing/image_174.jpg -> persistent-landing/images/image_1759054706722.jpg
# Moved: temporal-landing/image_175.jpg -> persistent-landing/images/image_1759054706733.jpg
# Moved: temporal-landing/image_176.jpg -> persistent-landing/images/image_1759054706747.jpg
# Moved: temporal-landing/image_177.jpg -> persistent-landing/images/image_1759054706758.jpg
# Moved: temporal-landing/image_178.jpg -> persistent-landing/images/image_1759054706769.jpg
# Moved: temporal-landing/image_179.jpg -> persistent-landing/images/image_1759054706779.jpg
# Moved: temporal-landing/image_18.jpg -> persistent-landing/images/image_1759054706790.jpg
# Moved: temporal-landing/image_180.jpg -> persistent-landing/images/image_1759054706800.jpg
# Moved: temporal-landing/image_181.jpg -> persistent-landing/images/image_1759054706816.jpg
# Moved: temporal-landing/image_182.jpg -> persistent-landing/images/image_1759054706827.jpg
# Moved: temporal-landing/image_183.jpg -> persistent-landing/images/image_1759054706845.jpg
# Moved: temporal-landing/image_184.jpg -> persistent-landing/images/image_1759054706857.jpg
# Moved: temporal-landing/image_185.jpg -> persistent-landing/images/image_1759054706868.jpg
# Moved: temporal-landing/image_186.jpg -> persistent-landing/images/image_1759054706880.jpg
# Moved: temporal-landing/image_187.jpg -> persistent-landing/images/image_1759054706891.jpg
# Moved: temporal-landing/image_188.jpg -> persistent-landing/images/image_1759054706902.jpg
# Moved: temporal-landing/image_189.jpg -> persistent-landing/images/image_1759054706914.jpg
# Moved: temporal-landing/image_19.jpg -> persistent-landing/images/image_1759054706926.jpg
# Moved: temporal-landing/image_190.jpg -> persistent-landing/images/image_1759054706938.jpg
# Moved: temporal-landing/image_191.jpg -> persistent-landing/images/image_1759054706949.jpg
# Moved: temporal-landing/image_192.jpg -> persistent-landing/images/image_1759054706962.jpg
# Moved: temporal-landing/image_193.jpg -> persistent-landing/images/image_1759054706984.jpg
# Moved: temporal-landing/image_194.jpg -> persistent-landing/images/image_1759054706994.jpg
# Moved: temporal-landing/image_195.jpg -> persistent-landing/images/image_1759054707007.jpg
# Moved: temporal-landing/image_196.jpg -> persistent-landing/images/image_1759054707025.jpg
# Moved: temporal-landing/image_197.jpg -> persistent-landing/images/image_1759054707047.jpg
# Moved: temporal-landing/image_198.jpg -> persistent-landing/images/image_1759054707058.jpg
# Moved: temporal-landing/image_199.jpg -> persistent-landing/images/image_1759054707070.jpg
# Moved: temporal-landing/image_2.jpg -> persistent-landing/images/image_1759054707084.jpg
# Moved: temporal-landing/image_20.jpg -> persistent-landing/images/image_1759054707094.jpg
# Moved: temporal-landing/image_200.jpg -> persistent-landing/images/image_1759054707106.jpg
# Moved: temporal-landing/image_21.jpg -> persistent-landing/images/image_1759054707118.jpg
# Moved: temporal-landing/image_22.jpg -> persistent-landing/images/image_1759054707129.jpg
# Moved: temporal-landing/image_23.jpg -> persistent-landing/images/image_1759054707138.jpg
# Moved: temporal-landing/image_24.jpg -> persistent-landing/images/image_1759054707149.jpg
# Moved: temporal-landing/image_25.jpg -> persistent-landing/images/image_1759054707159.jpg
# Moved: temporal-landing/image_26.jpg -> persistent-landing/images/image_1759054707169.jpg
# Moved: temporal-landing/image_27.jpg -> persistent-landing/images/image_1759054707180.jpg
# Moved: temporal-landing/image_28.jpg -> persistent-landing/images/image_1759054707189.jpg
# Moved: temporal-landing/image_29.jpg -> persistent-landing/images/image_1759054707199.jpg
# Moved: temporal-landing/image_3.jpg -> persistent-landing/images/image_1759054707210.jpg
# Moved: temporal-landing/image_30.jpg -> persistent-landing/images/image_1759054707224.jpg
# Moved: temporal-landing/image_31.jpg -> persistent-landing/images/image_1759054707237.jpg
# Moved: temporal-landing/image_32.jpg -> persistent-landing/images/image_1759054707247.jpg
# Moved: temporal-landing/image_33.jpg -> persistent-landing/images/image_1759054707257.jpg
# Moved: temporal-landing/image_34.jpg -> persistent-landing/images/image_1759054707267.jpg
# Moved: temporal-landing/image_35.jpg -> persistent-landing/images/image_1759054707276.jpg
# Moved: temporal-landing/image_36.jpg -> persistent-landing/images/image_1759054707286.jpg
# Moved: temporal-landing/image_37.jpg -> persistent-landing/images/image_1759054707297.jpg
# Moved: temporal-landing/image_38.jpg -> persistent-landing/images/image_1759054707307.jpg
# Moved: temporal-landing/image_39.jpg -> persistent-landing/images/image_1759054707317.jpg
# Moved: temporal-landing/image_4.jpg -> persistent-landing/images/image_1759054707326.jpg
# Moved: temporal-landing/image_40.jpg -> persistent-landing/images/image_1759054707336.jpg
# Moved: temporal-landing/image_41.jpg -> persistent-landing/images/image_1759054707347.jpg
# Moved: temporal-landing/image_42.jpg -> persistent-landing/images/image_1759054707356.jpg
# Moved: temporal-landing/image_43.jpg -> persistent-landing/images/image_1759054707367.jpg
# Moved: temporal-landing/image_44.jpg -> persistent-landing/images/image_1759054707377.jpg
# Moved: temporal-landing/image_45.jpg -> persistent-landing/images/image_1759054707387.jpg
# Moved: temporal-landing/image_46.jpg -> persistent-landing/images/image_1759054707397.jpg
# Moved: temporal-landing/image_47.jpg -> persistent-landing/images/image_1759054707408.jpg
# Moved: temporal-landing/image_48.jpg -> persistent-landing/images/image_1759054707417.jpg
# Moved: temporal-landing/image_49.jpg -> persistent-landing/images/image_1759054707428.jpg
# Moved: temporal-landing/image_5.jpg -> persistent-landing/images/image_1759054707440.jpg
# Moved: temporal-landing/image_50.jpg -> persistent-landing/images/image_1759054707453.jpg
# Moved: temporal-landing/image_51.jpg -> persistent-landing/images/image_1759054707464.jpg
# Moved: temporal-landing/image_52.jpg -> persistent-landing/images/image_1759054707475.jpg
# Moved: temporal-landing/image_53.jpg -> persistent-landing/images/image_1759054707486.jpg
# Moved: temporal-landing/image_54.jpg -> persistent-landing/images/image_1759054707497.jpg
# Moved: temporal-landing/image_55.jpg -> persistent-landing/images/image_1759054707509.jpg
# Moved: temporal-landing/image_56.jpg -> persistent-landing/images/image_1759054707520.jpg
# Moved: temporal-landing/image_57.jpg -> persistent-landing/images/image_1759054707531.jpg
# Moved: temporal-landing/image_58.jpg -> persistent-landing/images/image_1759054707541.jpg
# Moved: temporal-landing/image_59.jpg -> persistent-landing/images/image_1759054707554.jpg
# Moved: temporal-landing/image_6.jpg -> persistent-landing/images/image_1759054707566.jpg
# Moved: temporal-landing/image_60.jpg -> persistent-landing/images/image_1759054707577.jpg
# Moved: temporal-landing/image_61.jpg -> persistent-landing/images/image_1759054707589.jpg
# Moved: temporal-landing/image_62.jpg -> persistent-landing/images/image_1759054707599.jpg
# Moved: temporal-landing/image_63.jpg -> persistent-landing/images/image_1759054707609.jpg
# Moved: temporal-landing/image_64.jpg -> persistent-landing/images/image_1759054707619.jpg
# Moved: temporal-landing/image_65.jpg -> persistent-landing/images/image_1759054707630.jpg
# Moved: temporal-landing/image_66.jpg -> persistent-landing/images/image_1759054707639.jpg
# Moved: temporal-landing/image_67.jpg -> persistent-landing/images/image_1759054707655.jpg
# Moved: temporal-landing/image_68.jpg -> persistent-landing/images/image_1759054707669.jpg
# Moved: temporal-landing/image_69.jpg -> persistent-landing/images/image_1759054707695.jpg
# Moved: temporal-landing/image_7.jpg -> persistent-landing/images/image_1759054707705.jpg
# Moved: temporal-landing/image_70.jpg -> persistent-landing/images/image_1759054707715.jpg
# Moved: temporal-landing/image_71.jpg -> persistent-landing/images/image_1759054707725.jpg
# Moved: temporal-landing/image_72.jpg -> persistent-landing/images/image_1759054707735.jpg
# Moved: temporal-landing/image_73.jpg -> persistent-landing/images/image_1759054707746.jpg
# Moved: temporal-landing/image_74.jpg -> persistent-landing/images/image_1759054707756.jpg
# Moved: temporal-landing/image_75.jpg -> persistent-landing/images/image_1759054707767.jpg
# Moved: temporal-landing/image_76.jpg -> persistent-landing/images/image_1759054707776.jpg
# Moved: temporal-landing/image_77.jpg -> persistent-landing/images/image_1759054707787.jpg
# Moved: temporal-landing/image_78.jpg -> persistent-landing/images/image_1759054707797.jpg
# Moved: temporal-landing/image_79.jpg -> persistent-landing/images/image_1759054707807.jpg
# Moved: temporal-landing/image_8.jpg -> persistent-landing/images/image_1759054707819.jpg
# Moved: temporal-landing/image_80.jpg -> persistent-landing/images/image_1759054707829.jpg
# Moved: temporal-landing/image_81.jpg -> persistent-landing/images/image_1759054707838.jpg
# Moved: temporal-landing/image_82.jpg -> persistent-landing/images/image_1759054707849.jpg
# Moved: temporal-landing/image_83.jpg -> persistent-landing/images/image_1759054707860.jpg
# Moved: temporal-landing/image_84.jpg -> persistent-landing/images/image_1759054707875.jpg
# Moved: temporal-landing/image_85.jpg -> persistent-landing/images/image_1759054707884.jpg
# Moved: temporal-landing/image_86.jpg -> persistent-landing/images/image_1759054707893.jpg
# Moved: temporal-landing/image_87.jpg -> persistent-landing/images/image_1759054707903.jpg
# Moved: temporal-landing/image_88.jpg -> persistent-landing/images/image_1759054707914.jpg
# Moved: temporal-landing/image_89.jpg -> persistent-landing/images/image_1759054707924.jpg
# Moved: temporal-landing/image_9.jpg -> persistent-landing/images/image_1759054707934.jpg
# Moved: temporal-landing/image_90.jpg -> persistent-landing/images/image_1759054707944.jpg
# Moved: temporal-landing/image_91.jpg -> persistent-landing/images/image_1759054707954.jpg
# Moved: temporal-landing/image_92.jpg -> persistent-landing/images/image_1759054707964.jpg
# Moved: temporal-landing/image_93.jpg -> persistent-landing/images/image_1759054707974.jpg
# Moved: temporal-landing/image_94.jpg -> persistent-landing/images/image_1759054707984.jpg
# Moved: temporal-landing/image_95.jpg -> persistent-landing/images/image_1759054707994.jpg
# Moved: temporal-landing/image_96.jpg -> persistent-landing/images/image_1759054708003.jpg
# Moved: temporal-landing/image_97.jpg -> persistent-landing/images/image_1759054708013.jpg
# Moved: temporal-landing/image_98.jpg -> persistent-landing/images/image_1759054708022.jpg
# Moved: temporal-landing/image_99.jpg -> persistent-landing/images/image_1759054708032.jpg
# Moved: temporal-landing/text_1.txt -> persistent-landing/texts/text_1759054708041.txt
# Moved: temporal-landing/text_10.txt -> persistent-landing/texts/text_1759054708050.txt
# Moved: temporal-landing/text_100.txt -> persistent-landing/texts/text_1759054708059.txt
# Moved: temporal-landing/text_101.txt -> persistent-landing/texts/text_1759054708069.txt
# Moved: temporal-landing/text_102.txt -> persistent-landing/texts/text_1759054708080.txt
# Moved: temporal-landing/text_103.txt -> persistent-landing/texts/text_1759054708093.txt
# Moved: temporal-landing/text_104.txt -> persistent-landing/texts/text_1759054708102.txt
# Moved: temporal-landing/text_105.txt -> persistent-landing/texts/text_1759054708111.txt
# Moved: temporal-landing/text_106.txt -> persistent-landing/texts/text_1759054708121.txt
# Moved: temporal-landing/text_107.txt -> persistent-landing/texts/text_1759054708130.txt
# Moved: temporal-landing/text_108.txt -> persistent-landing/texts/text_1759054708140.txt
# Moved: temporal-landing/text_109.txt -> persistent-landing/texts/text_1759054708151.txt
# Moved: temporal-landing/text_11.txt -> persistent-landing/texts/text_1759054708163.txt
# Moved: temporal-landing/text_110.txt -> persistent-landing/texts/text_1759054708174.txt
# Moved: temporal-landing/text_111.txt -> persistent-landing/texts/text_1759054708185.txt
# Moved: temporal-landing/text_112.txt -> persistent-landing/texts/text_1759054708194.txt
# Moved: temporal-landing/text_113.txt -> persistent-landing/texts/text_1759054708205.txt
# Moved: temporal-landing/text_114.txt -> persistent-landing/texts/text_1759054708215.txt
# Moved: temporal-landing/text_115.txt -> persistent-landing/texts/text_1759054708224.txt
# Moved: temporal-landing/text_116.txt -> persistent-landing/texts/text_1759054708233.txt
# Moved: temporal-landing/text_117.txt -> persistent-landing/texts/text_1759054708244.txt
# Moved: temporal-landing/text_118.txt -> persistent-landing/texts/text_1759054708253.txt
# Moved: temporal-landing/text_119.txt -> persistent-landing/texts/text_1759054708263.txt
# Moved: temporal-landing/text_12.txt -> persistent-landing/texts/text_1759054708271.txt
# Moved: temporal-landing/text_120.txt -> persistent-landing/texts/text_1759054708281.txt
# Moved: temporal-landing/text_121.txt -> persistent-landing/texts/text_1759054708290.txt
# Moved: temporal-landing/text_122.txt -> persistent-landing/texts/text_1759054708302.txt
# Moved: temporal-landing/text_123.txt -> persistent-landing/texts/text_1759054708313.txt
# Moved: temporal-landing/text_124.txt -> persistent-landing/texts/text_1759054708322.txt
# Moved: temporal-landing/text_125.txt -> persistent-landing/texts/text_1759054708331.txt
# Moved: temporal-landing/text_126.txt -> persistent-landing/texts/text_1759054708340.txt
# Moved: temporal-landing/text_127.txt -> persistent-landing/texts/text_1759054708350.txt
# Moved: temporal-landing/text_128.txt -> persistent-landing/texts/text_1759054708360.txt
# Moved: temporal-landing/text_129.txt -> persistent-landing/texts/text_1759054708370.txt
# Moved: temporal-landing/text_13.txt -> persistent-landing/texts/text_1759054708380.txt
# Moved: temporal-landing/text_130.txt -> persistent-landing/texts/text_1759054708391.txt
# Moved: temporal-landing/text_131.txt -> persistent-landing/texts/text_1759054708402.txt
# Moved: temporal-landing/text_132.txt -> persistent-landing/texts/text_1759054708413.txt
# Moved: temporal-landing/text_133.txt -> persistent-landing/texts/text_1759054708424.txt
# Moved: temporal-landing/text_134.txt -> persistent-landing/texts/text_1759054708434.txt
# Moved: temporal-landing/text_135.txt -> persistent-landing/texts/text_1759054708443.txt
# Moved: temporal-landing/text_136.txt -> persistent-landing/texts/text_1759054708454.txt
# Moved: temporal-landing/text_137.txt -> persistent-landing/texts/text_1759054708463.txt
# Moved: temporal-landing/text_138.txt -> persistent-landing/texts/text_1759054708473.txt
# Moved: temporal-landing/text_139.txt -> persistent-landing/texts/text_1759054708489.txt
# Moved: temporal-landing/text_14.txt -> persistent-landing/texts/text_1759054708500.txt
# Moved: temporal-landing/text_140.txt -> persistent-landing/texts/text_1759054708511.txt
# Moved: temporal-landing/text_141.txt -> persistent-landing/texts/text_1759054708527.txt
# Moved: temporal-landing/text_142.txt -> persistent-landing/texts/text_1759054708546.txt
# Moved: temporal-landing/text_143.txt -> persistent-landing/texts/text_1759054708556.txt
# Moved: temporal-landing/text_144.txt -> persistent-landing/texts/text_1759054708567.txt
# Moved: temporal-landing/text_145.txt -> persistent-landing/texts/text_1759054708575.txt
# Moved: temporal-landing/text_146.txt -> persistent-landing/texts/text_1759054708586.txt
# Moved: temporal-landing/text_147.txt -> persistent-landing/texts/text_1759054708597.txt
# Moved: temporal-landing/text_148.txt -> persistent-landing/texts/text_1759054708606.txt
# Moved: temporal-landing/text_149.txt -> persistent-landing/texts/text_1759054708616.txt
# Moved: temporal-landing/text_15.txt -> persistent-landing/texts/text_1759054708624.txt
# Moved: temporal-landing/text_150.txt -> persistent-landing/texts/text_1759054708635.txt
# Moved: temporal-landing/text_151.txt -> persistent-landing/texts/text_1759054708643.txt
# Moved: temporal-landing/text_152.txt -> persistent-landing/texts/text_1759054708653.txt
# Moved: temporal-landing/text_153.txt -> persistent-landing/texts/text_1759054708662.txt
# Moved: temporal-landing/text_154.txt -> persistent-landing/texts/text_1759054708672.txt
# Moved: temporal-landing/text_155.txt -> persistent-landing/texts/text_1759054708682.txt
# Moved: temporal-landing/text_156.txt -> persistent-landing/texts/text_1759054708691.txt
# Moved: temporal-landing/text_157.txt -> persistent-landing/texts/text_1759054708700.txt
# Moved: temporal-landing/text_158.txt -> persistent-landing/texts/text_1759054708709.txt
# Moved: temporal-landing/text_159.txt -> persistent-landing/texts/text_1759054708719.txt
# Moved: temporal-landing/text_16.txt -> persistent-landing/texts/text_1759054708729.txt
# Moved: temporal-landing/text_160.txt -> persistent-landing/texts/text_1759054708741.txt
# Moved: temporal-landing/text_161.txt -> persistent-landing/texts/text_1759054708751.txt
# Moved: temporal-landing/text_162.txt -> persistent-landing/texts/text_1759054708759.txt
# Moved: temporal-landing/text_163.txt -> persistent-landing/texts/text_1759054708770.txt
# Moved: temporal-landing/text_164.txt -> persistent-landing/texts/text_1759054708779.txt
# Moved: temporal-landing/text_165.txt -> persistent-landing/texts/text_1759054708789.txt
# Moved: temporal-landing/text_166.txt -> persistent-landing/texts/text_1759054708799.txt
# Moved: temporal-landing/text_167.txt -> persistent-landing/texts/text_1759054708810.txt
# Moved: temporal-landing/text_168.txt -> persistent-landing/texts/text_1759054708820.txt
# Moved: temporal-landing/text_169.txt -> persistent-landing/texts/text_1759054708829.txt
# Moved: temporal-landing/text_17.txt -> persistent-landing/texts/text_1759054708839.txt
# Moved: temporal-landing/text_170.txt -> persistent-landing/texts/text_1759054708848.txt
# Moved: temporal-landing/text_171.txt -> persistent-landing/texts/text_1759054708857.txt
# Moved: temporal-landing/text_172.txt -> persistent-landing/texts/text_1759054708867.txt
# Moved: temporal-landing/text_173.txt -> persistent-landing/texts/text_1759054708875.txt
# Moved: temporal-landing/text_174.txt -> persistent-landing/texts/text_1759054708884.txt
# Moved: temporal-landing/text_175.txt -> persistent-landing/texts/text_1759054708893.txt
# Moved: temporal-landing/text_176.txt -> persistent-landing/texts/text_1759054708902.txt
# Moved: temporal-landing/text_177.txt -> persistent-landing/texts/text_1759054708912.txt
# Moved: temporal-landing/text_178.txt -> persistent-landing/texts/text_1759054708921.txt
# Moved: temporal-landing/text_179.txt -> persistent-landing/texts/text_1759054708932.txt
# Moved: temporal-landing/text_18.txt -> persistent-landing/texts/text_1759054708941.txt
# Moved: temporal-landing/text_180.txt -> persistent-landing/texts/text_1759054708953.txt
# Moved: temporal-landing/text_181.txt -> persistent-landing/texts/text_1759054708964.txt
# Moved: temporal-landing/text_182.txt -> persistent-landing/texts/text_1759054708974.txt
# Moved: temporal-landing/text_183.txt -> persistent-landing/texts/text_1759054708983.txt
# Moved: temporal-landing/text_184.txt -> persistent-landing/texts/text_1759054708992.txt
# Moved: temporal-landing/text_185.txt -> persistent-landing/texts/text_1759054709002.txt
# Moved: temporal-landing/text_186.txt -> persistent-landing/texts/text_1759054709011.txt
# Moved: temporal-landing/text_187.txt -> persistent-landing/texts/text_1759054709021.txt
# Moved: temporal-landing/text_188.txt -> persistent-landing/texts/text_1759054709029.txt
# Moved: temporal-landing/text_189.txt -> persistent-landing/texts/text_1759054709038.txt
# Moved: temporal-landing/text_19.txt -> persistent-landing/texts/text_1759054709047.txt
# Moved: temporal-landing/text_190.txt -> persistent-landing/texts/text_1759054709056.txt
# Moved: temporal-landing/text_191.txt -> persistent-landing/texts/text_1759054709065.txt
# Moved: temporal-landing/text_192.txt -> persistent-landing/texts/text_1759054709075.txt
# Moved: temporal-landing/text_193.txt -> persistent-landing/texts/text_1759054709083.txt
# Moved: temporal-landing/text_194.txt -> persistent-landing/texts/text_1759054709094.txt
# Moved: temporal-landing/text_195.txt -> persistent-landing/texts/text_1759054709105.txt
# Moved: temporal-landing/text_196.txt -> persistent-landing/texts/text_1759054709115.txt
# Moved: temporal-landing/text_197.txt -> persistent-landing/texts/text_1759054709124.txt
# Moved: temporal-landing/text_198.txt -> persistent-landing/texts/text_1759054709133.txt
# Moved: temporal-landing/text_199.txt -> persistent-landing/texts/text_1759054709143.txt
# Moved: temporal-landing/text_2.txt -> persistent-landing/texts/text_1759054709153.txt
# Moved: temporal-landing/text_20.txt -> persistent-landing/texts/text_1759054709162.txt
# Moved: temporal-landing/text_200.txt -> persistent-landing/texts/text_1759054709175.txt
# Moved: temporal-landing/text_21.txt -> persistent-landing/texts/text_1759054709186.txt
# Moved: temporal-landing/text_22.txt -> persistent-landing/texts/text_1759054709195.txt
# Moved: temporal-landing/text_23.txt -> persistent-landing/texts/text_1759054709203.txt
# Moved: temporal-landing/text_24.txt -> persistent-landing/texts/text_1759054709214.txt
# Moved: temporal-landing/text_25.txt -> persistent-landing/texts/text_1759054709223.txt
# Moved: temporal-landing/text_26.txt -> persistent-landing/texts/text_1759054709233.txt
# Moved: temporal-landing/text_27.txt -> persistent-landing/texts/text_1759054709243.txt
# Moved: temporal-landing/text_28.txt -> persistent-landing/texts/text_1759054709257.txt
# Moved: temporal-landing/text_29.txt -> persistent-landing/texts/text_1759054709268.txt
# Moved: temporal-landing/text_3.txt -> persistent-landing/texts/text_1759054709277.txt
# Moved: temporal-landing/text_30.txt -> persistent-landing/texts/text_1759054709287.txt
# Moved: temporal-landing/text_31.txt -> persistent-landing/texts/text_1759054709296.txt
# Moved: temporal-landing/text_32.txt -> persistent-landing/texts/text_1759054709305.txt
# Moved: temporal-landing/text_33.txt -> persistent-landing/texts/text_1759054709318.txt
# Moved: temporal-landing/text_34.txt -> persistent-landing/texts/text_1759054709332.txt
# Moved: temporal-landing/text_35.txt -> persistent-landing/texts/text_1759054709341.txt
# Moved: temporal-landing/text_36.txt -> persistent-landing/texts/text_1759054709351.txt
# Moved: temporal-landing/text_37.txt -> persistent-landing/texts/text_1759054709361.txt
# Moved: temporal-landing/text_38.txt -> persistent-landing/texts/text_1759054709373.txt
# Moved: temporal-landing/text_39.txt -> persistent-landing/texts/text_1759054709420.txt
# Moved: temporal-landing/text_4.txt -> persistent-landing/texts/text_1759054709444.txt
# Moved: temporal-landing/text_40.txt -> persistent-landing/texts/text_1759054709460.txt
# Moved: temporal-landing/text_41.txt -> persistent-landing/texts/text_1759054709471.txt
# Moved: temporal-landing/text_42.txt -> persistent-landing/texts/text_1759054709481.txt
# Moved: temporal-landing/text_43.txt -> persistent-landing/texts/text_1759054709491.txt
# Moved: temporal-landing/text_44.txt -> persistent-landing/texts/text_1759054709501.txt
# Moved: temporal-landing/text_45.txt -> persistent-landing/texts/text_1759054709510.txt
# Moved: temporal-landing/text_46.txt -> persistent-landing/texts/text_1759054709521.txt
# Moved: temporal-landing/text_47.txt -> persistent-landing/texts/text_1759054709531.txt
# Moved: temporal-landing/text_48.txt -> persistent-landing/texts/text_1759054709539.txt
# Moved: temporal-landing/text_49.txt -> persistent-landing/texts/text_1759054709549.txt
# Moved: temporal-landing/text_5.txt -> persistent-landing/texts/text_1759054709558.txt
# Moved: temporal-landing/text_50.txt -> persistent-landing/texts/text_1759054709568.txt
# Moved: temporal-landing/text_51.txt -> persistent-landing/texts/text_1759054709577.txt
# Moved: temporal-landing/text_52.txt -> persistent-landing/texts/text_1759054709590.txt
# Moved: temporal-landing/text_53.txt -> persistent-landing/texts/text_1759054709602.txt
# Moved: temporal-landing/text_54.txt -> persistent-landing/texts/text_1759054709616.txt
# Moved: temporal-landing/text_55.txt -> persistent-landing/texts/text_1759054709626.txt
# Moved: temporal-landing/text_56.txt -> persistent-landing/texts/text_1759054709635.txt
# Moved: temporal-landing/text_57.txt -> persistent-landing/texts/text_1759054709644.txt
# Moved: temporal-landing/text_58.txt -> persistent-landing/texts/text_1759054709654.txt
# Moved: temporal-landing/text_59.txt -> persistent-landing/texts/text_1759054709663.txt
# Moved: temporal-landing/text_6.txt -> persistent-landing/texts/text_1759054709672.txt
# Moved: temporal-landing/text_60.txt -> persistent-landing/texts/text_1759054709682.txt
# Moved: temporal-landing/text_61.txt -> persistent-landing/texts/text_1759054709691.txt
# Moved: temporal-landing/text_62.txt -> persistent-landing/texts/text_1759054709700.txt
# Moved: temporal-landing/text_63.txt -> persistent-landing/texts/text_1759054709709.txt
# Moved: temporal-landing/text_64.txt -> persistent-landing/texts/text_1759054709720.txt
# Moved: temporal-landing/text_65.txt -> persistent-landing/texts/text_1759054709730.txt
# Moved: temporal-landing/text_66.txt -> persistent-landing/texts/text_1759054709739.txt
# Moved: temporal-landing/text_67.txt -> persistent-landing/texts/text_1759054709748.txt
# Moved: temporal-landing/text_68.txt -> persistent-landing/texts/text_1759054709757.txt
# Moved: temporal-landing/text_69.txt -> persistent-landing/texts/text_1759054709766.txt
# Moved: temporal-landing/text_7.txt -> persistent-landing/texts/text_1759054709774.txt
# Moved: temporal-landing/text_70.txt -> persistent-landing/texts/text_1759054709784.txt
# Moved: temporal-landing/text_71.txt -> persistent-landing/texts/text_1759054709793.txt
# Moved: temporal-landing/text_72.txt -> persistent-landing/texts/text_1759054709804.txt
# Moved: temporal-landing/text_73.txt -> persistent-landing/texts/text_1759054709820.txt
# Moved: temporal-landing/text_74.txt -> persistent-landing/texts/text_1759054709831.txt
# Moved: temporal-landing/text_75.txt -> persistent-landing/texts/text_1759054709840.txt
# Moved: temporal-landing/text_76.txt -> persistent-landing/texts/text_1759054709850.txt
# Moved: temporal-landing/text_77.txt -> persistent-landing/texts/text_1759054709859.txt
# Moved: temporal-landing/text_78.txt -> persistent-landing/texts/text_1759054709869.txt
# Moved: temporal-landing/text_79.txt -> persistent-landing/texts/text_1759054709878.txt
# Moved: temporal-landing/text_8.txt -> persistent-landing/texts/text_1759054709888.txt
# Moved: temporal-landing/text_80.txt -> persistent-landing/texts/text_1759054709897.txt
# Moved: temporal-landing/text_81.txt -> persistent-landing/texts/text_1759054709906.txt
# Moved: temporal-landing/text_82.txt -> persistent-landing/texts/text_1759054709917.txt
# Moved: temporal-landing/text_83.txt -> persistent-landing/texts/text_1759054709926.txt
# Moved: temporal-landing/text_84.txt -> persistent-landing/texts/text_1759054709936.txt
# Moved: temporal-landing/text_85.txt -> persistent-landing/texts/text_1759054709945.txt
# Moved: temporal-landing/text_86.txt -> persistent-landing/texts/text_1759054709954.txt
# Moved: temporal-landing/text_87.txt -> persistent-landing/texts/text_1759054709964.txt
# Moved: temporal-landing/text_88.txt -> persistent-landing/texts/text_1759054709974.txt
# Moved: temporal-landing/text_89.txt -> persistent-landing/texts/text_1759054709984.txt
# Moved: temporal-landing/text_9.txt -> persistent-landing/texts/text_1759054709992.txt
# Moved: temporal-landing/text_90.txt -> persistent-landing/texts/text_1759054710002.txt
# Moved: temporal-landing/text_91.txt -> persistent-landing/texts/text_1759054710013.txt
# Moved: temporal-landing/text_92.txt -> persistent-landing/texts/text_1759054710027.txt
# Moved: temporal-landing/text_93.txt -> persistent-landing/texts/text_1759054710036.txt
# Moved: temporal-landing/text_94.txt -> persistent-landing/texts/text_1759054710046.txt
# Moved: temporal-landing/text_95.txt -> persistent-landing/texts/text_1759054710055.txt
# Moved: temporal-landing/text_96.txt -> persistent-landing/texts/text_1759054710065.txt
# Moved: temporal-landing/text_97.txt -> persistent-landing/texts/text_1759054710082.txt
# Moved: temporal-landing/text_98.txt -> persistent-landing/texts/text_1759054710092.txt
# Moved: temporal-landing/text_99.txt -> persistent-landing/texts/text_1759054710104.txt
# Moved: temporal-landing/video_1.mp4 -> persistent-landing/videos/video_1759054710115.mp4
# Moved: temporal-landing/video_2.mp4 -> persistent-landing/videos/video_1759054710203.mp4
# Moved: temporal-landing/video_3.mp4 -> persistent-landing/videos/video_1759054710254.mp4
# Moved: temporal-landing/video_4.mp4 -> persistent-landing/videos/video_1759054710296.mp4
# Moved: temporal-landing/video_5.mp4 -> persistent-landing/videos/video_1759054710348.mp4
