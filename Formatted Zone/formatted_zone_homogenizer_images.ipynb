# %% [markdown]
# ## Image Homogenizer

# %%
# Importing useful dependencies
import io
import os
import boto3
from PIL import Image

# %%
# Setup S3 client for MinIO (MinIO implements Amazon S3 API)
s3 = boto3.client(
    "s3",
    endpoint_url="http://127.0.0.1:9000", # MinIO API endpoint
    aws_access_key_id="minioadmin", # User name
    aws_secret_access_key="minioadmin", # Password
)

# %%
# This function scans a bucket folder, converts every non-PNG image it finds into PNG, uploads it back with the same name but .png extension, and deletes the original file.
def convert_images_to_png(bucket, prefix=""):
    paginator = s3.get_paginator("list_objects_v2")
    for page in paginator.paginate(Bucket=bucket, Prefix=prefix):
        for obj in page.get("Contents", []):

            if obj['Size'] == 0: # skip the folder itself
                continue

            key = obj["Key"]

            if os.path.splitext(key)[1].lower() == ".png": # skip png images
                continue

            # New key with .png extension
            new_key = os.path.splitext(key)[0] + ".png"

            # Download the image
            resp = s3.get_object(Bucket=bucket, Key=key)
            body = resp["Body"].read()
            
            # Convert to PNG
            img = Image.open(io.BytesIO(body)).convert("RGBA")
            buf = io.BytesIO()
            img.save(buf, format="PNG")
            buf.seek(0)

            # Upload the image back as PNG (replace original with .png)
            s3.upload_fileobj(buf, Bucket=bucket, Key=new_key, ExtraArgs={"ContentType": "image/png"})

            # Delete the old image
            s3.delete_object(Bucket=bucket, Key=key)

            print(f"Replaced: {key} -> {new_key}")

# %%
# Change the format of images to PNG
convert_images_to_png(bucket = "formatted-zone", prefix = "images/")
# Out:
# Replaced: images/image_1759091609544.jpg -> images/image_1759091609544.png
# Replaced: images/image_1759091609616.jpg -> images/image_1759091609616.png
# Replaced: images/image_1759091609673.jpg -> images/image_1759091609673.png
# Replaced: images/image_1759091609731.jpg -> images/image_1759091609731.png
# Replaced: images/image_1759091609808.jpg -> images/image_1759091609808.png
# Replaced: images/image_1759091609911.jpg -> images/image_1759091609911.png
# Replaced: images/image_1759091609988.jpg -> images/image_1759091609988.png
# Replaced: images/image_1759091610087.jpg -> images/image_1759091610087.png
# Replaced: images/image_1759091610172.jpg -> images/image_1759091610172.png
# Replaced: images/image_1759091610248.jpg -> images/image_1759091610248.png
# Replaced: images/image_1759091610328.jpg -> images/image_1759091610328.png
# Replaced: images/image_1759091610454.jpg -> images/image_1759091610454.png
# Replaced: images/image_1759091610514.jpg -> images/image_1759091610514.png
# Replaced: images/image_1759091610575.jpg -> images/image_1759091610575.png
# Replaced: images/image_1759091610699.jpg -> images/image_1759091610699.png
# Replaced: images/image_1759091610785.jpg -> images/image_1759091610785.png
# Replaced: images/image_1759091610863.jpg -> images/image_1759091610863.png
# Replaced: images/image_1759091610956.jpg -> images/image_1759091610956.png
# Replaced: images/image_1759091611033.jpg -> images/image_1759091611033.png
# Replaced: images/image_1759091611107.jpg -> images/image_1759091611107.png
# Replaced: images/image_1759091611181.jpg -> images/image_1759091611181.png
# Replaced: images/image_1759091611258.jpg -> images/image_1759091611258.png
# Replaced: images/image_1759091611339.jpg -> images/image_1759091611339.png
# Replaced: images/image_1759091611433.jpg -> images/image_1759091611433.png
# Replaced: images/image_1759091611492.jpg -> images/image_1759091611492.png
# Replaced: images/image_1759091611564.jpg -> images/image_1759091611564.png
# Replaced: images/image_1759091611641.jpg -> images/image_1759091611641.png
# Replaced: images/image_1759091611726.jpg -> images/image_1759091611726.png
# Replaced: images/image_1759091611794.jpg -> images/image_1759091611794.png
# Replaced: images/image_1759091611875.jpg -> images/image_1759091611875.png
# Replaced: images/image_1759091611988.jpg -> images/image_1759091611988.png
# Replaced: images/image_1759091612233.jpg -> images/image_1759091612233.png
# Replaced: images/image_1759091612400.jpg -> images/image_1759091612400.png
# Replaced: images/image_1759091612548.jpg -> images/image_1759091612548.png
# Replaced: images/image_1759091612664.jpg -> images/image_1759091612664.png
# Replaced: images/image_1759091612739.jpg -> images/image_1759091612739.png
# Replaced: images/image_1759091612811.jpg -> images/image_1759091612811.png
# Replaced: images/image_1759091612906.jpg -> images/image_1759091612906.png
# Replaced: images/image_1759091613006.jpg -> images/image_1759091613006.png
# Replaced: images/image_1759091613134.jpg -> images/image_1759091613134.png
# Replaced: images/image_1759091613212.jpg -> images/image_1759091613212.png
# Replaced: images/image_1759091613296.jpg -> images/image_1759091613296.png
# Replaced: images/image_1759091613378.jpg -> images/image_1759091613378.png
# Replaced: images/image_1759091613468.jpg -> images/image_1759091613468.png
# Replaced: images/image_1759091613538.jpg -> images/image_1759091613538.png
# Replaced: images/image_1759091613611.jpg -> images/image_1759091613611.png
# Replaced: images/image_1759091613672.jpg -> images/image_1759091613672.png
# Replaced: images/image_1759091613882.jpg -> images/image_1759091613882.png
# Replaced: images/image_1759091613940.jpg -> images/image_1759091613940.png
# Replaced: images/image_1759091614004.jpg -> images/image_1759091614004.png
# Replaced: images/image_1759091614082.jpg -> images/image_1759091614082.png
# Replaced: images/image_1759091614162.jpg -> images/image_1759091614162.png
# Replaced: images/image_1759091614312.jpg -> images/image_1759091614312.png
# Replaced: images/image_1759091614386.jpg -> images/image_1759091614386.png
# Replaced: images/image_1759091614461.jpg -> images/image_1759091614461.png
# Replaced: images/image_1759091614532.jpg -> images/image_1759091614532.png
# Replaced: images/image_1759091614631.jpg -> images/image_1759091614631.png
# Replaced: images/image_1759091614690.jpg -> images/image_1759091614690.png
# Replaced: images/image_1759091614771.jpg -> images/image_1759091614771.png
# Replaced: images/image_1759091614870.jpg -> images/image_1759091614870.png
# Replaced: images/image_1759091614946.jpg -> images/image_1759091614946.png
# Replaced: images/image_1759091615015.jpg -> images/image_1759091615015.png
# Replaced: images/image_1759091615091.jpg -> images/image_1759091615091.png
# Replaced: images/image_1759091615158.jpg -> images/image_1759091615158.png
# Replaced: images/image_1759091615231.jpg -> images/image_1759091615231.png
# Replaced: images/image_1759091615387.jpg -> images/image_1759091615387.png
# Replaced: images/image_1759091615506.jpg -> images/image_1759091615506.png
# Replaced: images/image_1759091615586.jpg -> images/image_1759091615586.png
# Replaced: images/image_1759091615664.jpg -> images/image_1759091615664.png
# Replaced: images/image_1759091615738.jpg -> images/image_1759091615738.png
# Replaced: images/image_1759091615809.jpg -> images/image_1759091615809.png
# Replaced: images/image_1759091615989.jpg -> images/image_1759091615989.png
# Replaced: images/image_1759091616062.jpg -> images/image_1759091616062.png
# Replaced: images/image_1759091616146.jpg -> images/image_1759091616146.png
# Replaced: images/image_1759091616222.jpg -> images/image_1759091616222.png
# Replaced: images/image_1759091616302.jpg -> images/image_1759091616302.png
# Replaced: images/image_1759091616374.jpg -> images/image_1759091616374.png
# Replaced: images/image_1759091616454.jpg -> images/image_1759091616454.png
# Replaced: images/image_1759091616519.jpg -> images/image_1759091616519.png
# Replaced: images/image_1759091616582.jpg -> images/image_1759091616582.png
# Replaced: images/image_1759091616673.jpg -> images/image_1759091616673.png
# Replaced: images/image_1759091616750.jpg -> images/image_1759091616750.png
# Replaced: images/image_1759091616825.jpg -> images/image_1759091616825.png
# Replaced: images/image_1759091616952.jpg -> images/image_1759091616952.png
# Replaced: images/image_1759091617029.jpg -> images/image_1759091617029.png
# Replaced: images/image_1759091617112.jpg -> images/image_1759091617112.png
# Replaced: images/image_1759091617196.jpg -> images/image_1759091617196.png
# Replaced: images/image_1759091617265.jpg -> images/image_1759091617265.png
# Replaced: images/image_1759091617334.jpg -> images/image_1759091617334.png
# Replaced: images/image_1759091617390.jpg -> images/image_1759091617390.png
# Replaced: images/image_1759091617453.jpg -> images/image_1759091617453.png
# Replaced: images/image_1759091617538.jpg -> images/image_1759091617538.png
# Replaced: images/image_1759091617615.jpg -> images/image_1759091617615.png
# Replaced: images/image_1759091617690.jpg -> images/image_1759091617690.png
# Replaced: images/image_1759091617767.jpg -> images/image_1759091617767.png
# Replaced: images/image_1759091617834.jpg -> images/image_1759091617834.png
# Replaced: images/image_1759091617913.jpg -> images/image_1759091617913.png
# Replaced: images/image_1759091617974.jpg -> images/image_1759091617974.png
# Replaced: images/image_1759091618042.jpg -> images/image_1759091618042.png
# Replaced: images/image_1759091618117.jpg -> images/image_1759091618117.png
# Replaced: images/image_1759091618216.jpg -> images/image_1759091618216.png
# Replaced: images/image_1759091618271.jpg -> images/image_1759091618271.png
# Replaced: images/image_1759091618344.jpg -> images/image_1759091618344.png
# Replaced: images/image_1759091618417.jpg -> images/image_1759091618417.png
# Replaced: images/image_1759091618540.jpg -> images/image_1759091618540.png
# Replaced: images/image_1759091618609.jpg -> images/image_1759091618609.png
# Replaced: images/image_1759091618682.jpg -> images/image_1759091618682.png
# Replaced: images/image_1759091618768.jpg -> images/image_1759091618768.png
# Replaced: images/image_1759091618848.jpg -> images/image_1759091618848.png
# Replaced: images/image_1759091618911.jpg -> images/image_1759091618911.png
# Replaced: images/image_1759091618992.jpg -> images/image_1759091618992.png
# Replaced: images/image_1759091619080.jpg -> images/image_1759091619080.png
# Replaced: images/image_1759091619136.jpg -> images/image_1759091619136.png
# Replaced: images/image_1759091619191.jpg -> images/image_1759091619191.png
# Replaced: images/image_1759091619276.jpg -> images/image_1759091619276.png
# Replaced: images/image_1759091619339.jpg -> images/image_1759091619339.png
# Replaced: images/image_1759091619398.jpg -> images/image_1759091619398.png
# Replaced: images/image_1759091619452.jpg -> images/image_1759091619452.png
# Replaced: images/image_1759091619519.jpg -> images/image_1759091619519.png
# Replaced: images/image_1759091619575.jpg -> images/image_1759091619575.png
# Replaced: images/image_1759091619657.jpg -> images/image_1759091619657.png
# Replaced: images/image_1759091619714.jpg -> images/image_1759091619714.png
# Replaced: images/image_1759091619777.jpg -> images/image_1759091619777.png
# Replaced: images/image_1759091619837.jpg -> images/image_1759091619837.png
# Replaced: images/image_1759091619892.jpg -> images/image_1759091619892.png
# Replaced: images/image_1759091619947.jpg -> images/image_1759091619947.png
# Replaced: images/image_1759091620008.jpg -> images/image_1759091620008.png
# Replaced: images/image_1759091620071.jpg -> images/image_1759091620071.png
# Replaced: images/image_1759091620136.jpg -> images/image_1759091620136.png
# Replaced: images/image_1759091620195.jpg -> images/image_1759091620195.png
# Replaced: images/image_1759091620255.jpg -> images/image_1759091620255.png
# Replaced: images/image_1759091620311.jpg -> images/image_1759091620311.png
# Replaced: images/image_1759091620366.jpg -> images/image_1759091620366.png
# Replaced: images/image_1759091620429.jpg -> images/image_1759091620429.png
# Replaced: images/image_1759091620506.jpg -> images/image_1759091620506.png
# Replaced: images/image_1759091620565.jpg -> images/image_1759091620565.png
# Replaced: images/image_1759091620623.jpg -> images/image_1759091620623.png
# Replaced: images/image_1759091620677.jpg -> images/image_1759091620677.png
# Replaced: images/image_1759091620739.jpg -> images/image_1759091620739.png
# Replaced: images/image_1759091620803.jpg -> images/image_1759091620803.png
# Replaced: images/image_1759091620859.jpg -> images/image_1759091620859.png
# Replaced: images/image_1759091620922.jpg -> images/image_1759091620922.png
# Replaced: images/image_1759091620990.jpg -> images/image_1759091620990.png
# Replaced: images/image_1759091621054.jpg -> images/image_1759091621054.png
# Replaced: images/image_1759091621120.jpg -> images/image_1759091621120.png
# Replaced: images/image_1759091621183.jpg -> images/image_1759091621183.png
# Replaced: images/image_1759091621289.jpg -> images/image_1759091621289.png
# Replaced: images/image_1759091621355.jpg -> images/image_1759091621355.png
# Replaced: images/image_1759091621421.jpg -> images/image_1759091621421.png
# Replaced: images/image_1759091621480.jpg -> images/image_1759091621480.png
# Replaced: images/image_1759091621542.jpg -> images/image_1759091621542.png
# Replaced: images/image_1759091621607.jpg -> images/image_1759091621607.png
# Replaced: images/image_1759091621665.jpg -> images/image_1759091621665.png
# Replaced: images/image_1759091621724.jpg -> images/image_1759091621724.png
# Replaced: images/image_1759091621851.jpg -> images/image_1759091621851.png
# Replaced: images/image_1759091621934.jpg -> images/image_1759091621934.png
# Replaced: images/image_1759091622134.jpg -> images/image_1759091622134.png
# Replaced: images/image_1759091622336.jpg -> images/image_1759091622336.png
# Replaced: images/image_1759091622647.jpg -> images/image_1759091622647.png
# Replaced: images/image_1759091622896.jpg -> images/image_1759091622896.png
# Replaced: images/image_1759091623146.jpg -> images/image_1759091623146.png
# Replaced: images/image_1759091623515.jpg -> images/image_1759091623515.png
# Replaced: images/image_1759091623789.jpg -> images/image_1759091623789.png
# Replaced: images/image_1759091624023.jpg -> images/image_1759091624023.png
# Replaced: images/image_1759091624208.jpg -> images/image_1759091624208.png
# Replaced: images/image_1759091624372.jpg -> images/image_1759091624372.png
# Replaced: images/image_1759091624521.jpg -> images/image_1759091624521.png
# Replaced: images/image_1759091624662.jpg -> images/image_1759091624662.png
# Replaced: images/image_1759091624817.jpg -> images/image_1759091624817.png
# Replaced: images/image_1759091624958.jpg -> images/image_1759091624958.png
# Replaced: images/image_1759091625078.jpg -> images/image_1759091625078.png
# Replaced: images/image_1759091625180.jpg -> images/image_1759091625180.png
# Replaced: images/image_1759091625272.jpg -> images/image_1759091625272.png
# Replaced: images/image_1759091625398.jpg -> images/image_1759091625398.png
# Replaced: images/image_1759091625569.jpg -> images/image_1759091625569.png
# Replaced: images/image_1759091625770.jpg -> images/image_1759091625770.png
# Replaced: images/image_1759091625884.jpg -> images/image_1759091625884.png
# Replaced: images/image_1759091625976.jpg -> images/image_1759091625976.png
# Replaced: images/image_1759091626106.jpg -> images/image_1759091626106.png
# Replaced: images/image_1759091626231.jpg -> images/image_1759091626231.png
# Replaced: images/image_1759091626328.jpg -> images/image_1759091626328.png
# Replaced: images/image_1759091626444.jpg -> images/image_1759091626444.png
# Replaced: images/image_1759091626613.jpg -> images/image_1759091626613.png
# Replaced: images/image_1759091626705.jpg -> images/image_1759091626705.png
# Replaced: images/image_1759091626796.jpg -> images/image_1759091626796.png
# Replaced: images/image_1759091626920.jpg -> images/image_1759091626920.png
# Replaced: images/image_1759091627038.jpg -> images/image_1759091627038.png
# Replaced: images/image_1759091627155.jpg -> images/image_1759091627155.png
# Replaced: images/image_1759091627245.jpg -> images/image_1759091627245.png
# Replaced: images/image_1759091627397.jpg -> images/image_1759091627397.png
# Replaced: images/image_1759091627481.jpg -> images/image_1759091627481.png
# Replaced: images/image_1759091627582.jpg -> images/image_1759091627582.png
# Replaced: images/image_1759091627668.jpg -> images/image_1759091627668.png
# Replaced: images/image_1759091627743.jpg -> images/image_1759091627743.png
# Replaced: images/image_1759091627824.jpg -> images/image_1759091627824.png
# Replaced: images/image_1759091627966.jpg -> images/image_1759091627966.png
# Replaced: images/image_1759091628075.jpg -> images/image_1759091628075.png
# Replaced: images/image_1759091628168.jpg -> images/image_1759091628168.png
# Replaced: images/image_1759091628291.jpg -> images/image_1759091628291.png
# Replaced: images/image_1759091628392.jpg -> images/image_1759091628392.png
