# %% [markdown]
# ## Text Homogenizer

# %%
# Importing useful dependencies
import io
import os
import boto3
import chardet
import docx
import fitz
import zipfile
from bs4 import BeautifulSoup
from odf.opendocument import load
from odf.text import P
from odf.teletype import extractText as odf_text
from striprtf.striprtf import rtf_to_text
import re
import markdown

# %%
# Setup S3 client for MinIO (MinIO implements Amazon S3 API)
s3 = boto3.client(
    "s3",
    endpoint_url="http://127.0.0.1:9000", # MinIO API endpoint
    aws_access_key_id="minioadmin", # User name
    aws_secret_access_key="minioadmin", # Password
)

# %%
# Define all function to extract text from other format

# Helper: normalize paragraph spacing
def _norm(s: str) -> str:
    """
    Normalize paragraph spacing in a text block.

    This helper function standardizes newline characters, removes leading/trailing
    whitespace, and ensures that paragraphs are separated by exactly one blank line.

    s          : str                   - Input text to normalize.
    """
    if not s:
        return ""
    s = s.replace("\r\n", "\n").replace("\r", "\n").strip()
    # Collapse 3 or more newlines into 2 (blank line between paragraphs)
    s = re.sub(r"\n{3,}", "\n\n", s)
    return s


def extract_from_docx(body: bytes) -> str:
    """
    Extract plain text from a DOCX document, preserving paragraph breaks.

    The function reads a DOCX file from raw bytes, collects non-empty paragraph
    texts in order, and joins them with a blank line between paragraphs.
    Final spacing is normalized via `_norm()`.

    This extracts `document.paragraphs` only.
    Text inside tables, headers/footers, text boxes/shapes, and comments is not included.

    body          : bytes                   - The raw bytes of a `.docx` file.
    """
    doc = docx.Document(io.BytesIO(body))

    # Gather non-empty paragraphs in order, trimming incidental whitespace.
    paragraphs = [p.text.strip() for p in doc.paragraphs if p.text and p.text.strip()]

    return _norm("\n\n".join(paragraphs))

def extract_from_pdf(body: bytes) -> str:
    """
    Extract plain text from a PDF by aggregating page text blocks.

    This approach uses PyMuPDF's block-level extraction to produce a more
    reliable paragraph grouping than line-by-line text.

    body          : bytes                   - The raw bytes of a `.pdf` file.
    """
    doc = fitz.open(stream=io.BytesIO(body), filetype="pdf")
    pages = []

    try:
        for i in range(len(doc)):

            # Each block is a tuple; index 0..4 commonly: (x0, y0, x1, y1, text, ...)
            blocks = doc.load_page(i).get_text("blocks")

            # Sort blocks by top (y0) then left (x0) to approximate natural reading order
            blocks.sort(key=lambda b: (b[1], b[0]))

            # Collect non-empty block texts; strip incidental whitespace
            txts = [b[4].strip() for b in blocks if b[4].strip()]
            # Separate blocks on the page with one blank line
            pages.append("\n\n".join(txts))

    finally:
        doc.close()


    return _norm("\n\n".join(pages))



def extract_from_zip(body: bytes) -> str:
    """
    Extract plain text from an EPUB or ZIP archive containing HTML/XHTML files.

    EPUB files are essentially ZIP archives with structured HTML content.
    This function scans the archive for all `.xhtml`, `.html`, or `.htm` files,
    extracts their readable text, and joins them in lexical order (sorted by
    filename) to approximate the book's original reading order.

    body          : bytes                   - Raw bytes of an EPUB or ZIP archive.

    """

    parts = []

    with zipfile.ZipFile(io.BytesIO(body)) as z:
        for name in sorted(z.namelist()):
            # Only process HTML/XHTML content files
            if name.lower().endswith((".xhtml", ".html", ".htm")):
                with z.open(name) as f:
                    # Parse HTML and extract visible text
                    soup = BeautifulSoup(f.read(), "html.parser")
                    text = soup.get_text("\n").strip()
                    if text:
                        parts.append(text)

    return _norm("\n\n".join(parts))


def extract_from_html(body: bytes) -> str:
    """
    Extract plain text from an HTML document while preserving structural line breaks.

    The function parses HTML content, strips away all markup, and retrieves only
    the visible text. A newline (`\\n`) is inserted between HTML elements to
    roughly preserve the visual separation of blocks (e.g., paragraphs, divs, headings).
    The resulting text is then normalized using `_norm()` to ensure clean paragraph spacing.

    body          : bytes                   -  Raw bytes of the HTML file or response content.
    """

    soup = BeautifulSoup(body, "html.parser")

    # Extract visible text from all tags, separating each block with a newline
    text = soup.get_text(separator="\n")

    return _norm(text)


def extract_from_odt(body: bytes) -> str:
    """
    Extract plain text from an OpenDocument Text (.odt) file, preserving paragraph breaks.

    This function opens an ODT document from raw bytes, iterates over all
    `<text:p>` paragraph elements, extracts their visible text using
    `teletype.extractText`, and joins non-empty paragraphs with a blank line.
    The final text is normalized via `_norm()` to ensure consistent spacing.

    body          : bytes                   -  Raw bytes of the `.odt` file.

    """

    # Open the ODT document directly from bytes
    doc = load(io.BytesIO(body))

    # Collect non-empty paragraph texts in order
    paragraphs = []
    for p in doc.getElementsByType(P):
        text = odf_text(p).strip()
        if text:
            paragraphs.append(text)

    return _norm("\n\n".join(paragraphs))


# RTF
def extract_from_rtf(body: bytes) -> str:
    """
    Extract plain text from an RTF document.

    The function tries to use `striprtf` (if installed) for robust RTF parsing.
    If `striprtf` is unavailable or parsing fails, it falls back to a simple
    heuristic that:
      - Replaces paragraph markers (e.g., ``\\par``) with blank lines,
      - Removes control words/groups and braces,
      - Leaves best-effort plain text.

    body          : bytes                   -  Raw bytes of the `.rtf` file.
    """
    try:
        # Preferred path: use striprtf if available
        text = rtf_to_text(body.decode("utf-8", errors="ignore"))

    # Fall through to heuristic cleanup
    except Exception:
        # Heuristic fallback: very rough RTF cleanup
        s = body.decode("utf-8", errors="ignore")

        # Replace paragraph control words with double newlines
        # \par and \pard → paragraph breaks
        s = re.sub(r"\\par[d]?", "\n\n", s)

        # Remove control groups like {\*\...} or {\fonttbl ...}, keep a space
        s = re.sub(r"{\\[^}]*}", " ", s)

        # Remove standalone control words (e.g., \b, \i, \fs24, \cf1, \u1234)
        s = re.sub(r"\\[a-zA-Z]+-?\d*", " ", s)

        # Remove remaining braces
        s = re.sub(r"[{}]", " ", s)
        text = s

    return _norm(text)


def extract_from_md(body: bytes) -> str:
    """
    Extract plain text from Markdown content by converting to HTML first.

    Converts Markdown to HTML using the standard 'markdown' module,
    then removes markup with BeautifulSoup, preserving paragraph spacing.

    body          : bytes                   -  Raw bytes of the `.md` file.
    """
    html = markdown.markdown(body.decode("utf-8", errors="ignore"))
    soup = BeautifulSoup(html, "html.parser")
    text = soup.get_text(separator="\n")
    return _norm(text)

# %%
# 1) map each extension to its extractor
EXT_MAP = {
    ".docx": extract_from_docx,
    ".pdf":  extract_from_pdf,
    ".epub": extract_from_zip,    # epub is a ZIP of XHTML/HTML
    ".zip":  extract_from_zip,
    ".html": extract_from_html,
    ".odt":  extract_from_odt,
    ".rtf":  extract_from_rtf,
    ".md":   extract_from_md,
}

def convert_and_replace(key, body):
    """
    Convert a supported document (PDF, DOCX, HTML, etc.) to plain text (.txt).

    This function performs content conversion only:
      - It detects the file extension,
      - Selects the correct extractor function from EXT_MAP,
      - Extracts plain text from the raw file bytes,
      - Returns both the converted text and the new filename.

    key             : str                   - Object key (path) within the bucket.
    body            : bytes                 - Raw file bytes to be converted.
    """

    # Determine the file extension and corresponding extractor function
    ext = os.path.splitext(key)[1].lower()
    extractor = EXT_MAP.get(ext)
    if extractor is None:
        return False, None, None

    try:
        content = extractor(body)
        name, _ = os.path.splitext(key)
        new_key = name + ".txt"
        return True, content, new_key
    except Exception as e:
        print(f"Failed to process {key}: {e}")
        return False, None, None

# %%
def convert_documents_to_txt(client, bucket, prefix=""):
    """
    Scan all objects under a given S3 prefix, normalize text encodings to UTF-8,
    and convert non-text documents (PDF, DOCX, HTML, etc.) into plain text (.txt).


    client          : obj                   - S3-compatible client (e.g., boto3.client("s3")).
    bucket          : str                   - Target S3/MinIO bucket.
    prefix          : str                   - Optional key prefix (acts like a folder path).

    """

    # Ensure path ends with '/'
    if prefix and not prefix.endswith("/"):
        prefix += "/"
    paginator = client.get_paginator("list_objects_v2")
    pages = paginator.paginate(Bucket=bucket, Prefix=prefix)

    for page in pages:
        for obj in page.get("Contents", []):

            if obj['Size'] == 0:  # Skip the folder itself (if the file size is 0)
                continue

            key = obj["Key"]

            try:
                # Get the file object from S3
                resp = client.get_object(Bucket=bucket, Key=key)
                body = resp["Body"].read()  # Read the file content

                # Case 1: plain text file (check encoding)
                if key.endswith(".txt"):
                    # Use chardet to detect the file encoding
                    result = chardet.detect(body)
                    current_encoding = result['encoding']
                    # Skip if the file is already in UTF-8 encoding
                    if current_encoding in ("utf-8", "ascii", None):
                        print(f"Already UTF-8 or ASCII: {key}")
                        continue

                    print(f"Converting {key} from {current_encoding} to UTF-8")

                    # Decode the content using the detected encoding and re-encode it in UTF-8
                    content = body.decode(current_encoding, errors='ignore')  # Ignore characters that can't be decoded
                    content = _norm(content)
                    # Upload the converted content back to S3 in UTF-8
                    client.put_object(
                        Bucket=bucket,
                        Key=key,  # Make sure the file key (path) is correct
                        Body=content.encode('utf-8'),
                        ContentType="text/plain"
                    )
                    print(f"Re-encoded {key} successfully")
                    
                else:
                    handled, content, new_key = convert_and_replace(key, body)
                    if handled:
                        client.put_object(
                            Bucket=bucket,
                            Key=new_key,
                            Body=content.encode("utf-8"),
                            ContentType="text/plain",
                        )
                        print(f"Converted {key} → {new_key}")

                    else:
                        print(f"Skipped unsupported extension: {key}")

            except Exception as e:
                print(f"Failed to process {key}: {e}")

# %%
convert_documents_to_txt(s3, bucket = "formatted-zone", prefix = "texts/")
# Out:
# Already UTF-8 or ASCII: texts/text_1761689048504.txt
# Already UTF-8 or ASCII: texts/text_1761689048588.txt
# Converting texts/text_1761689048672.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689048672.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689048788.txt
# Already UTF-8 or ASCII: texts/text_1761689048863.txt
# Converting texts/text_1761689048940.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1761689048940.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689049020.txt
# Already UTF-8 or ASCII: texts/text_1761689049098.txt
# Already UTF-8 or ASCII: texts/text_1761689049181.txt
# Already UTF-8 or ASCII: texts/text_1761689049258.txt
# Already UTF-8 or ASCII: texts/text_1761689049336.txt
# Already UTF-8 or ASCII: texts/text_1761689049412.txt
# Already UTF-8 or ASCII: texts/text_1761689049494.txt
# Already UTF-8 or ASCII: texts/text_1761689049589.txt
# Already UTF-8 or ASCII: texts/text_1761689049722.txt
# Already UTF-8 or ASCII: texts/text_1761689049821.txt
# Already UTF-8 or ASCII: texts/text_1761689049916.txt
# Already UTF-8 or ASCII: texts/text_1761689050015.txt
# Already UTF-8 or ASCII: texts/text_1761689050094.txt
# Already UTF-8 or ASCII: texts/text_1761689050175.txt
# Already UTF-8 or ASCII: texts/text_1761689050262.txt
# Already UTF-8 or ASCII: texts/text_1761689050340.txt
# Already UTF-8 or ASCII: texts/text_1761689050417.txt
# Already UTF-8 or ASCII: texts/text_1761689050503.txt
# Already UTF-8 or ASCII: texts/text_1761689050582.txt
# Converting texts/text_1761689050666.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689050666.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689050771.txt
# Already UTF-8 or ASCII: texts/text_1761689050858.txt
# Already UTF-8 or ASCII: texts/text_1761689050945.txt
# Already UTF-8 or ASCII: texts/text_1761689051034.txt
# Already UTF-8 or ASCII: texts/text_1761689051125.txt
# Already UTF-8 or ASCII: texts/text_1761689051219.txt
# Already UTF-8 or ASCII: texts/text_1761689051308.txt
# Already UTF-8 or ASCII: texts/text_1761689051440.txt
# Converting texts/text_1761689051666.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689051666.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689051909.txt
# Already UTF-8 or ASCII: texts/text_1761689052050.txt
# Already UTF-8 or ASCII: texts/text_1761689052195.txt
# Already UTF-8 or ASCII: texts/text_1761689052320.txt
# Already UTF-8 or ASCII: texts/text_1761689052554.txt
# Already UTF-8 or ASCII: texts/text_1761689052713.txt
# Already UTF-8 or ASCII: texts/text_1761689052833.txt
# Converting texts/text_1761689052970.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1761689052970.txt successfully
# Converting texts/text_1761689053087.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689053087.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689053188.txt
# Already UTF-8 or ASCII: texts/text_1761689053282.txt
# Already UTF-8 or ASCII: texts/text_1761689053372.txt
# Already UTF-8 or ASCII: texts/text_1761689053453.txt
# Already UTF-8 or ASCII: texts/text_1761689053540.txt
# Converting texts/text_1761689053633.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689053633.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689053710.txt
# Already UTF-8 or ASCII: texts/text_1761689053808.txt
# Already UTF-8 or ASCII: texts/text_1761689053914.txt
# Already UTF-8 or ASCII: texts/text_1761689053994.txt
# Already UTF-8 or ASCII: texts/text_1761689054079.txt
# Already UTF-8 or ASCII: texts/text_1761689054164.txt
# Already UTF-8 or ASCII: texts/text_1761689054241.txt
# Already UTF-8 or ASCII: texts/text_1761689054321.txt
# Already UTF-8 or ASCII: texts/text_1761689054405.txt
# Already UTF-8 or ASCII: texts/text_1761689054501.txt
# Already UTF-8 or ASCII: texts/text_1761689054749.txt
# Already UTF-8 or ASCII: texts/text_1761689054898.txt
# Converting texts/text_1761689055033.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1761689055033.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689055163.txt
# Converting texts/text_1761689055300.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689055300.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689055406.txt
# Already UTF-8 or ASCII: texts/text_1761689055492.txt
# Already UTF-8 or ASCII: texts/text_1761689055612.txt
# Already UTF-8 or ASCII: texts/text_1761689055748.txt
# Converting texts/text_1761689055879.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1761689055879.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689056027.txt
# Converting texts/text_1761689056174.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689056174.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689056337.txt
# Already UTF-8 or ASCII: texts/text_1761689056474.txt
# Already UTF-8 or ASCII: texts/text_1761689056612.txt
# Already UTF-8 or ASCII: texts/text_1761689056761.txt
# Already UTF-8 or ASCII: texts/text_1761689056895.txt
# Already UTF-8 or ASCII: texts/text_1761689057045.txt
# Already UTF-8 or ASCII: texts/text_1761689057146.txt
# Already UTF-8 or ASCII: texts/text_1761689057225.txt
# Already UTF-8 or ASCII: texts/text_1761689057311.txt
# Converting texts/text_1761689057381.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689057381.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689057459.txt
# Already UTF-8 or ASCII: texts/text_1761689057559.txt
# Already UTF-8 or ASCII: texts/text_1761689057632.txt
# Already UTF-8 or ASCII: texts/text_1761689057719.txt
# Already UTF-8 or ASCII: texts/text_1761689057800.txt
# Already UTF-8 or ASCII: texts/text_1761689057884.txt
# Already UTF-8 or ASCII: texts/text_1761689057979.txt
# Already UTF-8 or ASCII: texts/text_1761689058066.txt
# Already UTF-8 or ASCII: texts/text_1761689058174.txt
# Already UTF-8 or ASCII: texts/text_1761689058259.txt
# Already UTF-8 or ASCII: texts/text_1761689058343.txt
# Already UTF-8 or ASCII: texts/text_1761689058425.txt
# Converting texts/text_1761689058501.txt from MacRoman to UTF-8
# Re-encoded texts/text_1761689058501.txt successfully
# Converting texts/text_1761689058587.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1761689058587.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689058661.txt
# Already UTF-8 or ASCII: texts/text_1761689058736.txt
# Already UTF-8 or ASCII: texts/text_1761689058815.txt
# Already UTF-8 or ASCII: texts/text_1761689058894.txt
# Already UTF-8 or ASCII: texts/text_1761689058966.txt
# Already UTF-8 or ASCII: texts/text_1761689059049.txt
# Already UTF-8 or ASCII: texts/text_1761689059126.txt
# Already UTF-8 or ASCII: texts/text_1761689059203.txt
# Already UTF-8 or ASCII: texts/text_1761689059290.txt
# Already UTF-8 or ASCII: texts/text_1761689059364.txt
# Already UTF-8 or ASCII: texts/text_1761689059434.txt
# Already UTF-8 or ASCII: texts/text_1761689059511.txt
# Already UTF-8 or ASCII: texts/text_1761689059603.txt
# Already UTF-8 or ASCII: texts/text_1761689059686.txt
# Already UTF-8 or ASCII: texts/text_1761689059776.txt
# Already UTF-8 or ASCII: texts/text_1761689059863.txt
# Already UTF-8 or ASCII: texts/text_1761689059962.txt
# Already UTF-8 or ASCII: texts/text_1761689060059.txt
# Already UTF-8 or ASCII: texts/text_1761689060153.txt
# Already UTF-8 or ASCII: texts/text_1761689060259.txt
# Already UTF-8 or ASCII: texts/text_1761689060344.txt
# Already UTF-8 or ASCII: texts/text_1761689060420.txt
# Already UTF-8 or ASCII: texts/text_1761689060486.txt
# Already UTF-8 or ASCII: texts/text_1761689060581.txt
# Already UTF-8 or ASCII: texts/text_1761689060707.txt
# Already UTF-8 or ASCII: texts/text_1761689060829.txt
# Already UTF-8 or ASCII: texts/text_1761689060928.txt
# Already UTF-8 or ASCII: texts/text_1761689061002.txt
# Already UTF-8 or ASCII: texts/text_1761689061077.txt
# Already UTF-8 or ASCII: texts/text_1761689061157.txt
# Already UTF-8 or ASCII: texts/text_1761689061226.txt
# Already UTF-8 or ASCII: texts/text_1761689061295.txt
# Converting texts/text_1761689061365.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689061365.txt successfully
# Converting texts/text_1761689061495.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1761689061495.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689061756.txt
# Already UTF-8 or ASCII: texts/text_1761689061893.txt
# Already UTF-8 or ASCII: texts/text_1761689062032.txt
# Already UTF-8 or ASCII: texts/text_1761689062166.txt
# Already UTF-8 or ASCII: texts/text_1761689062289.txt
# Already UTF-8 or ASCII: texts/text_1761689062403.txt
# Already UTF-8 or ASCII: texts/text_1761689062519.txt
# Already UTF-8 or ASCII: texts/text_1761689062595.txt
# Already UTF-8 or ASCII: texts/text_1761689062679.txt
# Already UTF-8 or ASCII: texts/text_1761689062763.txt
# Already UTF-8 or ASCII: texts/text_1761689062846.txt
# Already UTF-8 or ASCII: texts/text_1761689062928.txt
# Converting texts/text_1761689063014.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1761689063014.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689063090.txt
# Already UTF-8 or ASCII: texts/text_1761689063159.txt
# Already UTF-8 or ASCII: texts/text_1761689063255.txt
# Already UTF-8 or ASCII: texts/text_1761689063361.txt
# Already UTF-8 or ASCII: texts/text_1761689063461.txt
# Converting texts/text_1761689063560.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689063560.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689063663.txt
# Already UTF-8 or ASCII: texts/text_1761689063747.txt
# Already UTF-8 or ASCII: texts/text_1761689063840.txt
# Already UTF-8 or ASCII: texts/text_1761689063933.txt
# Already UTF-8 or ASCII: texts/text_1761689064015.txt
# Already UTF-8 or ASCII: texts/text_1761689064105.txt
# Already UTF-8 or ASCII: texts/text_1761689064178.txt
# Already UTF-8 or ASCII: texts/text_1761689064253.txt
# Already UTF-8 or ASCII: texts/text_1761689064339.txt
# Already UTF-8 or ASCII: texts/text_1761689064561.txt
# Already UTF-8 or ASCII: texts/text_1761689064860.txt
# Already UTF-8 or ASCII: texts/text_1761689065071.txt
# Already UTF-8 or ASCII: texts/text_1761689065253.txt
# Already UTF-8 or ASCII: texts/text_1761689065408.txt
# Already UTF-8 or ASCII: texts/text_1761689065546.txt
# Already UTF-8 or ASCII: texts/text_1761689065679.txt
# Already UTF-8 or ASCII: texts/text_1761689065785.txt
# Already UTF-8 or ASCII: texts/text_1761689065872.txt
# Already UTF-8 or ASCII: texts/text_1761689065968.txt
# Already UTF-8 or ASCII: texts/text_1761689066074.txt
# Already UTF-8 or ASCII: texts/text_1761689066169.txt
# Already UTF-8 or ASCII: texts/text_1761689066257.txt
# Already UTF-8 or ASCII: texts/text_1761689066365.txt
# Already UTF-8 or ASCII: texts/text_1761689066475.txt
# Already UTF-8 or ASCII: texts/text_1761689066562.txt
# Already UTF-8 or ASCII: texts/text_1761689066673.txt
# Already UTF-8 or ASCII: texts/text_1761689066794.txt
# Already UTF-8 or ASCII: texts/text_1761689066876.txt
# Already UTF-8 or ASCII: texts/text_1761689066961.txt
# Already UTF-8 or ASCII: texts/text_1761689067097.txt
# Converting texts/text_1761689067184.txt from Windows-1254 to UTF-8
# Re-encoded texts/text_1761689067184.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689067266.txt
# Already UTF-8 or ASCII: texts/text_1761689067365.txt
# Already UTF-8 or ASCII: texts/text_1761689067494.txt
# Already UTF-8 or ASCII: texts/text_1761689067621.txt
# Already UTF-8 or ASCII: texts/text_1761689067738.txt
# Already UTF-8 or ASCII: texts/text_1761689067850.txt
# Already UTF-8 or ASCII: texts/text_1761689067958.txt
# Already UTF-8 or ASCII: texts/text_1761689068112.txt
# Already UTF-8 or ASCII: texts/text_1761689068250.txt
# Converting texts/text_1761689068377.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689068377.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689068505.txt
# Converting texts/text_1761689068637.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1761689068637.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689068723.txt
# Already UTF-8 or ASCII: texts/text_1761689068821.txt
# Already UTF-8 or ASCII: texts/text_1761689068913.txt
# Already UTF-8 or ASCII: texts/text_1761689068997.txt
# Already UTF-8 or ASCII: texts/text_1761689069077.txt
# Already UTF-8 or ASCII: texts/text_1761689069203.txt
# Already UTF-8 or ASCII: texts/text_1761689069288.txt
# Already UTF-8 or ASCII: texts/text_1761689069368.txt
# Already UTF-8 or ASCII: texts/text_1761689069456.txt
# Already UTF-8 or ASCII: texts/text_1761689069532.txt
# Already UTF-8 or ASCII: texts/text_1761689069611.txt
# Converting texts/text_1761689069713.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689069713.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689069809.txt
# Already UTF-8 or ASCII: texts/text_1761689069886.txt
# Already UTF-8 or ASCII: texts/text_1761689069977.txt
# Already UTF-8 or ASCII: texts/text_1761689070059.txt
# Already UTF-8 or ASCII: texts/text_1761689070145.txt
# Already UTF-8 or ASCII: texts/text_1761689070223.txt
# Already UTF-8 or ASCII: texts/text_1761689070301.txt
# Already UTF-8 or ASCII: texts/text_1761689070380.txt
# Already UTF-8 or ASCII: texts/text_1761689070477.txt
# Already UTF-8 or ASCII: texts/text_1761689070572.txt
# Already UTF-8 or ASCII: texts/text_1761689070654.txt
# Already UTF-8 or ASCII: texts/text_1761689070734.txt
# Already UTF-8 or ASCII: texts/text_1761689070814.txt
# Already UTF-8 or ASCII: texts/text_1761689070931.txt
# Converting texts/text_1761689071030.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689071030.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689071109.txt
# Already UTF-8 or ASCII: texts/text_1761689071185.txt
# Already UTF-8 or ASCII: texts/text_1761689071261.txt
# Already UTF-8 or ASCII: texts/text_1761689071344.txt
# Already UTF-8 or ASCII: texts/text_1761689071468.txt
# Already UTF-8 or ASCII: texts/text_1761689071750.txt
# Already UTF-8 or ASCII: texts/text_1761689071976.txt
# Already UTF-8 or ASCII: texts/text_1761689072137.txt
# Already UTF-8 or ASCII: texts/text_1761689072296.txt
# Already UTF-8 or ASCII: texts/text_1761689072436.txt
# Already UTF-8 or ASCII: texts/text_1761689072566.txt
# Already UTF-8 or ASCII: texts/text_1761689072659.txt
# Already UTF-8 or ASCII: texts/text_1761689072748.txt
# Converting texts/text_1761689072841.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689072841.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689072927.txt
# Already UTF-8 or ASCII: texts/text_1761689073051.txt
# Already UTF-8 or ASCII: texts/text_1761689073176.txt
# Already UTF-8 or ASCII: texts/text_1761689073266.txt
# Already UTF-8 or ASCII: texts/text_1761689073349.txt
# Already UTF-8 or ASCII: texts/text_1761689073425.txt
# Converting texts/text_1761689073510.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689073510.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689073627.txt
# Already UTF-8 or ASCII: texts/text_1761689073741.txt
# Already UTF-8 or ASCII: texts/text_1761689073817.txt
# Already UTF-8 or ASCII: texts/text_1761689073902.txt
# Converting texts/text_1761689074030.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689074030.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689074113.txt
# Already UTF-8 or ASCII: texts/text_1761689074208.txt
# Already UTF-8 or ASCII: texts/text_1761689074292.txt
# Already UTF-8 or ASCII: texts/text_1761689074402.txt
# Already UTF-8 or ASCII: texts/text_1761689074563.txt
# Already UTF-8 or ASCII: texts/text_1761689074871.txt
# Already UTF-8 or ASCII: texts/text_1761689075029.txt
# Converting texts/text_1761689075174.txt from MacRoman to UTF-8
# Re-encoded texts/text_1761689075174.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689075318.txt
# Already UTF-8 or ASCII: texts/text_1761689075440.txt
# Already UTF-8 or ASCII: texts/text_1761689075568.txt
# Already UTF-8 or ASCII: texts/text_1761689075654.txt
# Already UTF-8 or ASCII: texts/text_1761689075781.txt
# Already UTF-8 or ASCII: texts/text_1761689075880.txt
# Already UTF-8 or ASCII: texts/text_1761689075991.txt
# Already UTF-8 or ASCII: texts/text_1761689076092.txt
# Already UTF-8 or ASCII: texts/text_1761689076255.txt
# Already UTF-8 or ASCII: texts/text_1761689076365.txt
# Already UTF-8 or ASCII: texts/text_1761689076483.txt
# Already UTF-8 or ASCII: texts/text_1761689076593.txt
# Already UTF-8 or ASCII: texts/text_1761689076688.txt
# Already UTF-8 or ASCII: texts/text_1761689076787.txt
# Already UTF-8 or ASCII: texts/text_1761689076888.txt
# Already UTF-8 or ASCII: texts/text_1761689076976.txt
# Already UTF-8 or ASCII: texts/text_1761689077094.txt
# Converting texts/text_1761689077192.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689077192.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689077291.txt
# Already UTF-8 or ASCII: texts/text_1761689077433.txt
# Already UTF-8 or ASCII: texts/text_1761689077531.txt
# Already UTF-8 or ASCII: texts/text_1761689077618.txt
# Already UTF-8 or ASCII: texts/text_1761689077705.txt
# Converting texts/text_1761689077788.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689077788.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689077869.txt
# Already UTF-8 or ASCII: texts/text_1761689077964.txt
# Already UTF-8 or ASCII: texts/text_1761689078062.txt
# Already UTF-8 or ASCII: texts/text_1761689078140.txt
# Already UTF-8 or ASCII: texts/text_1761689078318.txt
# Already UTF-8 or ASCII: texts/text_1761689078415.txt
# Already UTF-8 or ASCII: texts/text_1761689078499.txt
# Already UTF-8 or ASCII: texts/text_1761689078595.txt
# Already UTF-8 or ASCII: texts/text_1761689078738.txt
# Already UTF-8 or ASCII: texts/text_1761689078898.txt
# Already UTF-8 or ASCII: texts/text_1761689079055.txt
# Already UTF-8 or ASCII: texts/text_1761689079228.txt
# Already UTF-8 or ASCII: texts/text_1761689079361.txt
# Already UTF-8 or ASCII: texts/text_1761689079503.txt
# Already UTF-8 or ASCII: texts/text_1761689079660.txt
# Already UTF-8 or ASCII: texts/text_1761689079806.txt
# Converting texts/text_1761689079908.txt from Windows-1254 to UTF-8
# Re-encoded texts/text_1761689079908.txt successfully
# Converting texts/text_1761689080091.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689080091.txt successfully
# Converting texts/text_1761689080221.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689080221.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689080306.txt
# Already UTF-8 or ASCII: texts/text_1761689080418.txt
# Already UTF-8 or ASCII: texts/text_1761689080499.txt
# Already UTF-8 or ASCII: texts/text_1761689080626.txt
# Already UTF-8 or ASCII: texts/text_1761689080726.txt
# Already UTF-8 or ASCII: texts/text_1761689080855.txt
# Already UTF-8 or ASCII: texts/text_1761689080979.txt
# Already UTF-8 or ASCII: texts/text_1761689081076.txt
# Converting texts/text_1761689081174.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689081174.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689081272.txt
# Already UTF-8 or ASCII: texts/text_1761689081373.txt
# Already UTF-8 or ASCII: texts/text_1761689081493.txt
# Already UTF-8 or ASCII: texts/text_1761689081845.txt
# Already UTF-8 or ASCII: texts/text_1761689082082.txt
# Already UTF-8 or ASCII: texts/text_1761689082259.txt
# Already UTF-8 or ASCII: texts/text_1761689082422.txt
# Already UTF-8 or ASCII: texts/text_1761689082605.txt
# Already UTF-8 or ASCII: texts/text_1761689082717.txt
# Already UTF-8 or ASCII: texts/text_1761689082808.txt
# Already UTF-8 or ASCII: texts/text_1761689082895.txt
# Already UTF-8 or ASCII: texts/text_1761689083030.txt
# Already UTF-8 or ASCII: texts/text_1761689083136.txt
# Already UTF-8 or ASCII: texts/text_1761689083240.txt
# Already UTF-8 or ASCII: texts/text_1761689083328.txt
# Already UTF-8 or ASCII: texts/text_1761689083413.txt
# Already UTF-8 or ASCII: texts/text_1761689083504.txt
# Converting texts/text_1761689083585.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689083585.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689083685.txt
# Converting texts/text_1761689083808.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689083808.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689083908.txt
# Already UTF-8 or ASCII: texts/text_1761689083993.txt
# Already UTF-8 or ASCII: texts/text_1761689084109.txt
# Already UTF-8 or ASCII: texts/text_1761689084252.txt
# Already UTF-8 or ASCII: texts/text_1761689084351.txt
# Already UTF-8 or ASCII: texts/text_1761689084432.txt
# Already UTF-8 or ASCII: texts/text_1761689084559.txt
# Already UTF-8 or ASCII: texts/text_1761689084838.txt
# Already UTF-8 or ASCII: texts/text_1761689084986.txt
# Already UTF-8 or ASCII: texts/text_1761689085194.txt
# Already UTF-8 or ASCII: texts/text_1761689085374.txt
# Already UTF-8 or ASCII: texts/text_1761689085618.txt
# Already UTF-8 or ASCII: texts/text_1761689085783.txt
# Already UTF-8 or ASCII: texts/text_1761689085946.txt
# Already UTF-8 or ASCII: texts/text_1761689086059.txt
# Already UTF-8 or ASCII: texts/text_1761689086158.txt
# Already UTF-8 or ASCII: texts/text_1761689086266.txt
# Already UTF-8 or ASCII: texts/text_1761689086363.txt
# Already UTF-8 or ASCII: texts/text_1761689086453.txt
# Already UTF-8 or ASCII: texts/text_1761689086550.txt
# Converting texts/text_1761689086640.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689086640.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689086731.txt
# Already UTF-8 or ASCII: texts/text_1761689086827.txt
# Already UTF-8 or ASCII: texts/text_1761689086907.txt
# Converting texts/text_1761689086988.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689086988.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689087075.txt
# Already UTF-8 or ASCII: texts/text_1761689087144.txt
# Already UTF-8 or ASCII: texts/text_1761689087232.txt
# Already UTF-8 or ASCII: texts/text_1761689087361.txt
# Already UTF-8 or ASCII: texts/text_1761689087481.txt
# Already UTF-8 or ASCII: texts/text_1761689087612.txt
# Already UTF-8 or ASCII: texts/text_1761689087746.txt
# Converting texts/text_1761689087875.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689087875.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689088045.txt
# Already UTF-8 or ASCII: texts/text_1761689088199.txt
# Already UTF-8 or ASCII: texts/text_1761689088344.txt
# Already UTF-8 or ASCII: texts/text_1761689088469.txt
# Already UTF-8 or ASCII: texts/text_1761689088613.txt
# Already UTF-8 or ASCII: texts/text_1761689088793.txt
# Already UTF-8 or ASCII: texts/text_1761689088992.txt
# Already UTF-8 or ASCII: texts/text_1761689089211.txt
# Already UTF-8 or ASCII: texts/text_1761689089401.txt
# Already UTF-8 or ASCII: texts/text_1761689089706.txt
# Already UTF-8 or ASCII: texts/text_1761689089925.txt
# Already UTF-8 or ASCII: texts/text_1761689090137.txt
# Converting texts/text_1761689090339.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689090339.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689090539.txt
# Already UTF-8 or ASCII: texts/text_1761689090713.txt
# Already UTF-8 or ASCII: texts/text_1761689090881.txt
# Already UTF-8 or ASCII: texts/text_1761689091081.txt
# Already UTF-8 or ASCII: texts/text_1761689091253.txt
# Already UTF-8 or ASCII: texts/text_1761689091442.txt
# Already UTF-8 or ASCII: texts/text_1761689091836.txt
# Already UTF-8 or ASCII: texts/text_1761689092162.txt
# Already UTF-8 or ASCII: texts/text_1761689092434.txt
# Already UTF-8 or ASCII: texts/text_1761689092662.txt
# Already UTF-8 or ASCII: texts/text_1761689092881.txt
# Already UTF-8 or ASCII: texts/text_1761689093106.txt
# Already UTF-8 or ASCII: texts/text_1761689093313.txt
# Already UTF-8 or ASCII: texts/text_1761689093538.txt
# Already UTF-8 or ASCII: texts/text_1761689093786.txt
# Already UTF-8 or ASCII: texts/text_1761689093977.txt
# Already UTF-8 or ASCII: texts/text_1761689094173.txt
# Already UTF-8 or ASCII: texts/text_1761689094381.txt
# Already UTF-8 or ASCII: texts/text_1761689094584.txt
# Already UTF-8 or ASCII: texts/text_1761689094913.txt
# Converting texts/text_1761689095132.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689095132.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689095387.txt
# Already UTF-8 or ASCII: texts/text_1761689095594.txt
# Already UTF-8 or ASCII: texts/text_1761689095784.txt
# Already UTF-8 or ASCII: texts/text_1761689095992.txt
# Already UTF-8 or ASCII: texts/text_1761689096161.txt
# Already UTF-8 or ASCII: texts/text_1761689096278.txt
# Already UTF-8 or ASCII: texts/text_1761689096381.txt
# Converting texts/text_1761689096477.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689096477.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689096582.txt
# Already UTF-8 or ASCII: texts/text_1761689096721.txt
# Already UTF-8 or ASCII: texts/text_1761689096885.txt
# Already UTF-8 or ASCII: texts/text_1761689096995.txt
# Already UTF-8 or ASCII: texts/text_1761689097092.txt
# Already UTF-8 or ASCII: texts/text_1761689097181.txt
# Already UTF-8 or ASCII: texts/text_1761689097264.txt
# Already UTF-8 or ASCII: texts/text_1761689097364.txt
# Already UTF-8 or ASCII: texts/text_1761689097462.txt
# Converting texts/text_1761689097548.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689097548.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689097658.txt
# Already UTF-8 or ASCII: texts/text_1761689097761.txt
# Converting texts/text_1761689097849.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689097849.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689097927.txt
# Already UTF-8 or ASCII: texts/text_1761689098024.txt
# Already UTF-8 or ASCII: texts/text_1761689098115.txt
# Already UTF-8 or ASCII: texts/text_1761689098207.txt
# Already UTF-8 or ASCII: texts/text_1761689098298.txt
# Already UTF-8 or ASCII: texts/text_1761689098381.txt
# Converting texts/text_1761689098515.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689098515.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689098621.txt
# Already UTF-8 or ASCII: texts/text_1761689098714.txt
# Already UTF-8 or ASCII: texts/text_1761689098832.txt
# Already UTF-8 or ASCII: texts/text_1761689098920.txt
# Already UTF-8 or ASCII: texts/text_1761689099008.txt
# Already UTF-8 or ASCII: texts/text_1761689099105.txt
# Already UTF-8 or ASCII: texts/text_1761689099187.txt
# Already UTF-8 or ASCII: texts/text_1761689099278.txt
# Already UTF-8 or ASCII: texts/text_1761689099393.txt
# Already UTF-8 or ASCII: texts/text_1761689099500.txt
# Already UTF-8 or ASCII: texts/text_1761689099596.txt
# Already UTF-8 or ASCII: texts/text_1761689099688.txt
# Already UTF-8 or ASCII: texts/text_1761689099770.txt
# Already UTF-8 or ASCII: texts/text_1761689099858.txt
# Already UTF-8 or ASCII: texts/text_1761689099954.txt
# Already UTF-8 or ASCII: texts/text_1761689100047.txt
# Already UTF-8 or ASCII: texts/text_1761689100153.txt
# Already UTF-8 or ASCII: texts/text_1761689100237.txt
# Already UTF-8 or ASCII: texts/text_1761689100313.txt
# Already UTF-8 or ASCII: texts/text_1761689100391.txt
# Converting texts/text_1761689100481.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689100481.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689100614.txt
# Converting texts/text_1761689100737.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689100737.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689100841.txt
# Already UTF-8 or ASCII: texts/text_1761689100976.txt
# Already UTF-8 or ASCII: texts/text_1761689101087.txt
# Already UTF-8 or ASCII: texts/text_1761689101190.txt
# Already UTF-8 or ASCII: texts/text_1761689101282.txt
# Already UTF-8 or ASCII: texts/text_1761689101365.txt
# Already UTF-8 or ASCII: texts/text_1761689101502.txt
# Already UTF-8 or ASCII: texts/text_1761689101812.txt
# Already UTF-8 or ASCII: texts/text_1761689102110.txt
# Already UTF-8 or ASCII: texts/text_1761689102308.txt
# Converting texts/text_1761689102492.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689102492.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689102639.txt
# Already UTF-8 or ASCII: texts/text_1761689102787.txt
# Already UTF-8 or ASCII: texts/text_1761689102958.txt
# Already UTF-8 or ASCII: texts/text_1761689103125.txt
# Already UTF-8 or ASCII: texts/text_1761689103273.txt
# Converting texts/text_1761689103414.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689103414.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689103550.txt
# Already UTF-8 or ASCII: texts/text_1761689103674.txt
# Already UTF-8 or ASCII: texts/text_1761689103798.txt
# Already UTF-8 or ASCII: texts/text_1761689103927.txt
# Already UTF-8 or ASCII: texts/text_1761689104067.txt
# Already UTF-8 or ASCII: texts/text_1761689104201.txt
# Already UTF-8 or ASCII: texts/text_1761689104336.txt
# Already UTF-8 or ASCII: texts/text_1761689104478.txt
# Already UTF-8 or ASCII: texts/text_1761689104798.txt
# Already UTF-8 or ASCII: texts/text_1761689104977.txt
# Converting texts/text_1761689105153.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689105153.txt successfully
# Converting texts/text_1761689105349.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689105349.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689105516.txt
# Already UTF-8 or ASCII: texts/text_1761689105710.txt
# Already UTF-8 or ASCII: texts/text_1761689105848.txt
# Already UTF-8 or ASCII: texts/text_1761689106002.txt
# Converting texts/text_1761689106153.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689106153.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689106285.txt
# Already UTF-8 or ASCII: texts/text_1761689106416.txt
# Already UTF-8 or ASCII: texts/text_1761689106559.txt
# Already UTF-8 or ASCII: texts/text_1761689106748.txt
# Already UTF-8 or ASCII: texts/text_1761689106879.txt
# Already UTF-8 or ASCII: texts/text_1761689107025.txt
# Already UTF-8 or ASCII: texts/text_1761689107165.txt
# Already UTF-8 or ASCII: texts/text_1761689107293.txt
# Already UTF-8 or ASCII: texts/text_1761689107442.txt
# Already UTF-8 or ASCII: texts/text_1761689107556.txt
# Already UTF-8 or ASCII: texts/text_1761689107665.txt
# Already UTF-8 or ASCII: texts/text_1761689107784.txt
# Already UTF-8 or ASCII: texts/text_1761689107917.txt
# Already UTF-8 or ASCII: texts/text_1761689108044.txt
# Converting texts/text_1761689108178.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689108178.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689108303.txt
# Already UTF-8 or ASCII: texts/text_1761689108453.txt
# Converting texts/text_1761689108556.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689108556.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689108639.txt
# Already UTF-8 or ASCII: texts/text_1761689108721.txt
# Already UTF-8 or ASCII: texts/text_1761689108792.txt
# Already UTF-8 or ASCII: texts/text_1761689108864.txt
# Already UTF-8 or ASCII: texts/text_1761689108944.txt
# Already UTF-8 or ASCII: texts/text_1761689109036.txt
# Already UTF-8 or ASCII: texts/text_1761689109117.txt
# Already UTF-8 or ASCII: texts/text_1761689109195.txt
# Converting texts/text_1761689109267.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689109267.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689109339.txt
# Already UTF-8 or ASCII: texts/text_1761689109436.txt
# Already UTF-8 or ASCII: texts/text_1761689109526.txt
# Already UTF-8 or ASCII: texts/text_1761689109620.txt
# Already UTF-8 or ASCII: texts/text_1761689109710.txt
# Already UTF-8 or ASCII: texts/text_1761689109798.txt
# Already UTF-8 or ASCII: texts/text_1761689109873.txt
# Already UTF-8 or ASCII: texts/text_1761689109967.txt
# Already UTF-8 or ASCII: texts/text_1761689110073.txt
# Already UTF-8 or ASCII: texts/text_1761689110142.txt
# Already UTF-8 or ASCII: texts/text_1761689110220.txt
# Already UTF-8 or ASCII: texts/text_1761689110294.txt
# Already UTF-8 or ASCII: texts/text_1761689110369.txt
# Already UTF-8 or ASCII: texts/text_1761689110450.txt
# Already UTF-8 or ASCII: texts/text_1761689110524.txt
# Already UTF-8 or ASCII: texts/text_1761689110599.txt
# Already UTF-8 or ASCII: texts/text_1761689110683.txt
# Already UTF-8 or ASCII: texts/text_1761689110755.txt
# Converting texts/text_1761689110828.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689110828.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689110920.txt
# Converting texts/text_1761689110991.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689110991.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689111074.txt
# Already UTF-8 or ASCII: texts/text_1761689111154.txt
# Already UTF-8 or ASCII: texts/text_1761689111227.txt
# Already UTF-8 or ASCII: texts/text_1761689111309.txt
# Converting texts/text_1761689111402.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689111402.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689111570.txt
# Already UTF-8 or ASCII: texts/text_1761689111800.txt
# Converting texts/text_1761689112033.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689112033.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689112174.txt
# Already UTF-8 or ASCII: texts/text_1761689112310.txt
# Already UTF-8 or ASCII: texts/text_1761689112448.txt
# Already UTF-8 or ASCII: texts/text_1761689112563.txt
# Already UTF-8 or ASCII: texts/text_1761689112737.txt
# Already UTF-8 or ASCII: texts/text_1761689112893.txt
# Converting texts/text_1761689112998.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689112998.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689113084.txt
# Already UTF-8 or ASCII: texts/text_1761689113178.txt
# Already UTF-8 or ASCII: texts/text_1761689113268.txt
# Already UTF-8 or ASCII: texts/text_1761689113348.txt
# Converting texts/text_1761689113422.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689113422.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689113498.txt
# Already UTF-8 or ASCII: texts/text_1761689113580.txt
# Already UTF-8 or ASCII: texts/text_1761689113671.txt
# Already UTF-8 or ASCII: texts/text_1761689113781.txt
# Already UTF-8 or ASCII: texts/text_1761689113874.txt
# Already UTF-8 or ASCII: texts/text_1761689113988.txt
# Already UTF-8 or ASCII: texts/text_1761689114072.txt
# Converting texts/text_1761689114162.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689114162.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689114244.txt
# Converting texts/text_1761689114345.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689114345.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689114435.txt
# Converting texts/text_1761689114519.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689114519.txt successfully
# Converting texts/text_1761689114734.txt from Windows-1254 to UTF-8
# Re-encoded texts/text_1761689114734.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689114878.txt
# Already UTF-8 or ASCII: texts/text_1761689115004.txt
# Converting texts/text_1761689115124.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689115124.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689115270.txt
# Already UTF-8 or ASCII: texts/text_1761689115384.txt
# Already UTF-8 or ASCII: texts/text_1761689115464.txt
# Already UTF-8 or ASCII: texts/text_1761689115574.txt
# Already UTF-8 or ASCII: texts/text_1761689115673.txt
# Already UTF-8 or ASCII: texts/text_1761689115752.txt
# Already UTF-8 or ASCII: texts/text_1761689115848.txt
# Already UTF-8 or ASCII: texts/text_1761689115951.txt
# Already UTF-8 or ASCII: texts/text_1761689116029.txt
# Already UTF-8 or ASCII: texts/text_1761689116109.txt
# Already UTF-8 or ASCII: texts/text_1761689116186.txt
# Already UTF-8 or ASCII: texts/text_1761689116262.txt
# Already UTF-8 or ASCII: texts/text_1761689116358.txt
# Already UTF-8 or ASCII: texts/text_1761689116427.txt
# Converting texts/text_1761689116515.txt from MacRoman to UTF-8
# Re-encoded texts/text_1761689116515.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689116603.txt
# Converting texts/text_1761689116696.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689116696.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689116775.txt
# Already UTF-8 or ASCII: texts/text_1761689116872.txt
# Converting texts/text_1761689116945.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689116945.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689117035.txt
# Already UTF-8 or ASCII: texts/text_1761689117116.txt
# Already UTF-8 or ASCII: texts/text_1761689117189.txt
# Already UTF-8 or ASCII: texts/text_1761689117262.txt
# Already UTF-8 or ASCII: texts/text_1761689117356.txt
# Converting texts/text_1761689117429.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1761689117429.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689117518.txt
# Already UTF-8 or ASCII: texts/text_1761689117632.txt
# Already UTF-8 or ASCII: texts/text_1761689117747.txt
# Converting texts/text_1761689117835.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689117835.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689117943.txt
# Already UTF-8 or ASCII: texts/text_1761689118047.txt
# Already UTF-8 or ASCII: texts/text_1761689118135.txt
# Already UTF-8 or ASCII: texts/text_1761689118228.txt
# Already UTF-8 or ASCII: texts/text_1761689118307.txt
# Already UTF-8 or ASCII: texts/text_1761689118386.txt
# Already UTF-8 or ASCII: texts/text_1761689118483.txt
# Already UTF-8 or ASCII: texts/text_1761689118584.txt
# Already UTF-8 or ASCII: texts/text_1761689118706.txt
# Converting texts/text_1761689118810.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689118810.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689118885.txt
# Converting texts/text_1761689118981.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689118981.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689119065.txt
# Converting texts/text_1761689119142.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689119142.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689119223.txt
# Already UTF-8 or ASCII: texts/text_1761689119298.txt
# Already UTF-8 or ASCII: texts/text_1761689119381.txt
# Already UTF-8 or ASCII: texts/text_1761689119465.txt
# Already UTF-8 or ASCII: texts/text_1761689119543.txt
# Already UTF-8 or ASCII: texts/text_1761689119630.txt
# Already UTF-8 or ASCII: texts/text_1761689119710.txt
# Converting texts/text_1761689119795.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689119795.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689119883.txt
# Already UTF-8 or ASCII: texts/text_1761689119973.txt
# Converting texts/text_1761689120054.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689120054.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689120144.txt
# Already UTF-8 or ASCII: texts/text_1761689120228.txt
# Already UTF-8 or ASCII: texts/text_1761689120295.txt
# Already UTF-8 or ASCII: texts/text_1761689120383.txt
# Already UTF-8 or ASCII: texts/text_1761689120465.txt
# Already UTF-8 or ASCII: texts/text_1761689120563.txt
# Already UTF-8 or ASCII: texts/text_1761689120661.txt
# Converting texts/text_1761689120750.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1761689120750.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689120825.txt
# Already UTF-8 or ASCII: texts/text_1761689120900.txt
# Converting texts/text_1761689120981.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689120981.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689121053.txt
# Converting texts/text_1761689121126.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689121126.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689121204.txt
# Already UTF-8 or ASCII: texts/text_1761689121282.txt
# Already UTF-8 or ASCII: texts/text_1761689121357.txt
# Already UTF-8 or ASCII: texts/text_1761689121438.txt
# Already UTF-8 or ASCII: texts/text_1761689121649.txt
# Already UTF-8 or ASCII: texts/text_1761689121898.txt
# Already UTF-8 or ASCII: texts/text_1761689122051.txt
# Already UTF-8 or ASCII: texts/text_1761689122200.txt
# Already UTF-8 or ASCII: texts/text_1761689122360.txt
# Already UTF-8 or ASCII: texts/text_1761689122549.txt
# Already UTF-8 or ASCII: texts/text_1761689122700.txt
# Converting texts/text_1761689122834.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689122834.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689122945.txt
# Already UTF-8 or ASCII: texts/text_1761689123053.txt
# Already UTF-8 or ASCII: texts/text_1761689123153.txt
# Already UTF-8 or ASCII: texts/text_1761689123262.txt
# Already UTF-8 or ASCII: texts/text_1761689123393.txt
# Already UTF-8 or ASCII: texts/text_1761689123523.txt
# Already UTF-8 or ASCII: texts/text_1761689123620.txt
# Already UTF-8 or ASCII: texts/text_1761689123708.txt
# Already UTF-8 or ASCII: texts/text_1761689123796.txt
# Already UTF-8 or ASCII: texts/text_1761689123886.txt
# Already UTF-8 or ASCII: texts/text_1761689124024.txt
# Already UTF-8 or ASCII: texts/text_1761689124122.txt
# Already UTF-8 or ASCII: texts/text_1761689124210.txt
# Already UTF-8 or ASCII: texts/text_1761689124319.txt
# Already UTF-8 or ASCII: texts/text_1761689124427.txt
# Already UTF-8 or ASCII: texts/text_1761689124524.txt
# Already UTF-8 or ASCII: texts/text_1761689124802.txt
# Already UTF-8 or ASCII: texts/text_1761689124950.txt
# Already UTF-8 or ASCII: texts/text_1761689125110.txt
# Already UTF-8 or ASCII: texts/text_1761689125268.txt
# Already UTF-8 or ASCII: texts/text_1761689125410.txt
# Already UTF-8 or ASCII: texts/text_1761689125510.txt
# Already UTF-8 or ASCII: texts/text_1761689125641.txt
# Converting texts/text_1761689125741.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689125741.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689125850.txt
# Converting texts/text_1761689125938.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689125938.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689126038.txt
# Already UTF-8 or ASCII: texts/text_1761689126127.txt
# Already UTF-8 or ASCII: texts/text_1761689126207.txt
# Already UTF-8 or ASCII: texts/text_1761689126281.txt
# Already UTF-8 or ASCII: texts/text_1761689126380.txt
# Converting texts/text_1761689126507.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689126507.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689126650.txt
# Already UTF-8 or ASCII: texts/text_1761689126770.txt
# Already UTF-8 or ASCII: texts/text_1761689126861.txt
# Converting texts/text_1761689126944.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689126944.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689127070.txt
# Converting texts/text_1761689127158.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689127158.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689127241.txt
# Already UTF-8 or ASCII: texts/text_1761689127331.txt
# Already UTF-8 or ASCII: texts/text_1761689127450.txt
# Converting texts/text_1761689127537.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689127537.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689127631.txt
# Already UTF-8 or ASCII: texts/text_1761689127725.txt
# Already UTF-8 or ASCII: texts/text_1761689127814.txt
# Already UTF-8 or ASCII: texts/text_1761689127893.txt
# Already UTF-8 or ASCII: texts/text_1761689127983.txt
# Already UTF-8 or ASCII: texts/text_1761689128068.txt
# Already UTF-8 or ASCII: texts/text_1761689128207.txt
# Already UTF-8 or ASCII: texts/text_1761689128294.txt
# Already UTF-8 or ASCII: texts/text_1761689128390.txt
# Already UTF-8 or ASCII: texts/text_1761689128483.txt
# Converting texts/text_1761689128578.txt from MacRoman to UTF-8
# Re-encoded texts/text_1761689128578.txt successfully
# Converting texts/text_1761689128681.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689128681.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689128774.txt
# Already UTF-8 or ASCII: texts/text_1761689128858.txt
# Already UTF-8 or ASCII: texts/text_1761689128944.txt
# Converting texts/text_1761689129075.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689129075.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689129161.txt
# Already UTF-8 or ASCII: texts/text_1761689129245.txt
# Already UTF-8 or ASCII: texts/text_1761689129342.txt
# Already UTF-8 or ASCII: texts/text_1761689129434.txt
# Already UTF-8 or ASCII: texts/text_1761689129536.txt
# Already UTF-8 or ASCII: texts/text_1761689129646.txt
# Already UTF-8 or ASCII: texts/text_1761689129725.txt
# Already UTF-8 or ASCII: texts/text_1761689129824.txt
# Already UTF-8 or ASCII: texts/text_1761689129939.txt
# Converting texts/text_1761689130060.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689130060.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689130149.txt
# Already UTF-8 or ASCII: texts/text_1761689130237.txt
# Already UTF-8 or ASCII: texts/text_1761689130333.txt
# Already UTF-8 or ASCII: texts/text_1761689130433.txt
# Already UTF-8 or ASCII: texts/text_1761689130546.txt
# Already UTF-8 or ASCII: texts/text_1761689130629.txt
# Already UTF-8 or ASCII: texts/text_1761689130713.txt
# Already UTF-8 or ASCII: texts/text_1761689130816.txt
# Already UTF-8 or ASCII: texts/text_1761689130913.txt
# Already UTF-8 or ASCII: texts/text_1761689130994.txt
# Converting texts/text_1761689131107.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689131107.txt successfully
# Converting texts/text_1761689131227.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689131227.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689131345.txt
# Converting texts/text_1761689131430.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689131430.txt successfully
# Converting texts/text_1761689131643.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689131643.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689131979.txt
# Already UTF-8 or ASCII: texts/text_1761689132155.txt
# Already UTF-8 or ASCII: texts/text_1761689132319.txt
# Already UTF-8 or ASCII: texts/text_1761689132495.txt
# Already UTF-8 or ASCII: texts/text_1761689132658.txt
# Already UTF-8 or ASCII: texts/text_1761689132795.txt
# Converting texts/text_1761689132918.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689132918.txt successfully
# Converting texts/text_1761689133044.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689133044.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689133150.txt
# Already UTF-8 or ASCII: texts/text_1761689133238.txt
# Already UTF-8 or ASCII: texts/text_1761689133336.txt
# Converting texts/text_1761689133438.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689133438.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689133536.txt
# Already UTF-8 or ASCII: texts/text_1761689133627.txt
# Already UTF-8 or ASCII: texts/text_1761689133729.txt
# Already UTF-8 or ASCII: texts/text_1761689133806.txt
# Already UTF-8 or ASCII: texts/text_1761689133887.txt
# Converting texts/text_1761689134007.txt from MacRoman to UTF-8
# Re-encoded texts/text_1761689134007.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689134119.txt
# Already UTF-8 or ASCII: texts/text_1761689134211.txt
# Already UTF-8 or ASCII: texts/text_1761689134347.txt
# Already UTF-8 or ASCII: texts/text_1761689134439.txt
# Already UTF-8 or ASCII: texts/text_1761689134520.txt
# Already UTF-8 or ASCII: texts/text_1761689134683.txt
# Already UTF-8 or ASCII: texts/text_1761689134862.txt
# Already UTF-8 or ASCII: texts/text_1761689135001.txt
# Already UTF-8 or ASCII: texts/text_1761689135117.txt
# Converting texts/text_1761689135251.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689135251.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689135413.txt
# Already UTF-8 or ASCII: texts/text_1761689135576.txt
# Already UTF-8 or ASCII: texts/text_1761689135677.txt
# Already UTF-8 or ASCII: texts/text_1761689135761.txt
# Already UTF-8 or ASCII: texts/text_1761689135882.txt
# Already UTF-8 or ASCII: texts/text_1761689136015.txt
# Already UTF-8 or ASCII: texts/text_1761689136136.txt
# Already UTF-8 or ASCII: texts/text_1761689136246.txt
# Already UTF-8 or ASCII: texts/text_1761689136322.txt
# Already UTF-8 or ASCII: texts/text_1761689136400.txt
# Already UTF-8 or ASCII: texts/text_1761689136492.txt
# Converting texts/text_1761689136568.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689136568.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689136659.txt
# Already UTF-8 or ASCII: texts/text_1761689136744.txt
# Already UTF-8 or ASCII: texts/text_1761689136847.txt
# Already UTF-8 or ASCII: texts/text_1761689136929.txt
# Already UTF-8 or ASCII: texts/text_1761689137003.txt
# Already UTF-8 or ASCII: texts/text_1761689137076.txt
# Already UTF-8 or ASCII: texts/text_1761689137161.txt
# Already UTF-8 or ASCII: texts/text_1761689137289.txt
# Already UTF-8 or ASCII: texts/text_1761689137381.txt
# Already UTF-8 or ASCII: texts/text_1761689137471.txt
# Already UTF-8 or ASCII: texts/text_1761689137544.txt
# Converting texts/text_1761689137627.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689137627.txt successfully
# Converting texts/text_1761689137704.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689137704.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689137773.txt
# Already UTF-8 or ASCII: texts/text_1761689137845.txt
# Already UTF-8 or ASCII: texts/text_1761689137917.txt
# Already UTF-8 or ASCII: texts/text_1761689137988.txt
# Already UTF-8 or ASCII: texts/text_1761689138069.txt
# Already UTF-8 or ASCII: texts/text_1761689138148.txt
# Already UTF-8 or ASCII: texts/text_1761689138219.txt
# Already UTF-8 or ASCII: texts/text_1761689138296.txt
# Already UTF-8 or ASCII: texts/text_1761689138376.txt
# Already UTF-8 or ASCII: texts/text_1761689138468.txt
# Already UTF-8 or ASCII: texts/text_1761689138552.txt
# Already UTF-8 or ASCII: texts/text_1761689138631.txt
# Converting texts/text_1761689138705.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689138705.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689138786.txt
# Already UTF-8 or ASCII: texts/text_1761689138860.txt
# Converting texts/text_1761689138936.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689138936.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689139038.txt
# Already UTF-8 or ASCII: texts/text_1761689139110.txt
# Already UTF-8 or ASCII: texts/text_1761689139187.txt
# Already UTF-8 or ASCII: texts/text_1761689139267.txt
# Already UTF-8 or ASCII: texts/text_1761689139360.txt
# Converting texts/text_1761689139423.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689139423.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689139504.txt
# Converting texts/text_1761689139585.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1761689139585.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689139657.txt
# Already UTF-8 or ASCII: texts/text_1761689139738.txt
# Already UTF-8 or ASCII: texts/text_1761689139818.txt
# Already UTF-8 or ASCII: texts/text_1761689139892.txt
# Already UTF-8 or ASCII: texts/text_1761689139984.txt
# Already UTF-8 or ASCII: texts/text_1761689140108.txt
# Already UTF-8 or ASCII: texts/text_1761689140232.txt
# Already UTF-8 or ASCII: texts/text_1761689140332.txt
# Already UTF-8 or ASCII: texts/text_1761689140399.txt
# Already UTF-8 or ASCII: texts/text_1761689140475.txt
# Converting texts/text_1761689140542.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689140542.txt successfully
# Converting texts/text_1761689140614.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1761689140614.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689140708.txt
# Already UTF-8 or ASCII: texts/text_1761689140786.txt
# Already UTF-8 or ASCII: texts/text_1761689140870.txt
# Already UTF-8 or ASCII: texts/text_1761689140962.txt
# Already UTF-8 or ASCII: texts/text_1761689141036.txt
# Already UTF-8 or ASCII: texts/text_1761689141125.txt
# Converting texts/text_1761689141202.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689141202.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689141271.txt
# Already UTF-8 or ASCII: texts/text_1761689141339.txt
# Already UTF-8 or ASCII: texts/text_1761689141408.txt
# Already UTF-8 or ASCII: texts/text_1761689141527.txt
# Already UTF-8 or ASCII: texts/text_1761689141724.txt
# Already UTF-8 or ASCII: texts/text_1761689141936.txt
# Already UTF-8 or ASCII: texts/text_1761689142100.txt
# Already UTF-8 or ASCII: texts/text_1761689142264.txt
# Already UTF-8 or ASCII: texts/text_1761689142401.txt
# Already UTF-8 or ASCII: texts/text_1761689142540.txt
# Already UTF-8 or ASCII: texts/text_1761689142678.txt
# Already UTF-8 or ASCII: texts/text_1761689142765.txt
# Converting texts/text_1761689142839.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689142839.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689142921.txt
# Already UTF-8 or ASCII: texts/text_1761689143006.txt
# Already UTF-8 or ASCII: texts/text_1761689143083.txt
# Already UTF-8 or ASCII: texts/text_1761689143164.txt
# Already UTF-8 or ASCII: texts/text_1761689143272.txt
# Already UTF-8 or ASCII: texts/text_1761689143349.txt
# Converting texts/text_1761689143434.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689143434.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689143558.txt
# Converting texts/text_1761689143676.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689143676.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689143761.txt
# Already UTF-8 or ASCII: texts/text_1761689143853.txt
# Already UTF-8 or ASCII: texts/text_1761689143976.txt
# Converting texts/text_1761689144117.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689144117.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689144245.txt
# Already UTF-8 or ASCII: texts/text_1761689144365.txt
# Already UTF-8 or ASCII: texts/text_1761689144488.txt
# Converting texts/text_1761689144683.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689144683.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689144890.txt
# Already UTF-8 or ASCII: texts/text_1761689145072.txt
# Already UTF-8 or ASCII: texts/text_1761689145235.txt
# Already UTF-8 or ASCII: texts/text_1761689145381.txt
# Converting texts/text_1761689145530.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689145530.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689145679.txt
# Already UTF-8 or ASCII: texts/text_1761689145822.txt
# Converting texts/text_1761689145950.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689145950.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689146081.txt
# Already UTF-8 or ASCII: texts/text_1761689146199.txt
# Already UTF-8 or ASCII: texts/text_1761689146318.txt
# Already UTF-8 or ASCII: texts/text_1761689146441.txt
# Already UTF-8 or ASCII: texts/text_1761689146605.txt
# Already UTF-8 or ASCII: texts/text_1761689146734.txt
# Already UTF-8 or ASCII: texts/text_1761689146867.txt
# Already UTF-8 or ASCII: texts/text_1761689147018.txt
# Already UTF-8 or ASCII: texts/text_1761689147155.txt
# Already UTF-8 or ASCII: texts/text_1761689147299.txt
# Already UTF-8 or ASCII: texts/text_1761689147473.txt
# Already UTF-8 or ASCII: texts/text_1761689147638.txt
# Already UTF-8 or ASCII: texts/text_1761689147768.txt
# Already UTF-8 or ASCII: texts/text_1761689147896.txt
# Already UTF-8 or ASCII: texts/text_1761689148022.txt
# Already UTF-8 or ASCII: texts/text_1761689148161.txt
# Converting texts/text_1761689148312.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1761689148312.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689148412.txt
# Already UTF-8 or ASCII: texts/text_1761689148496.txt
# Already UTF-8 or ASCII: texts/text_1761689148594.txt
# Already UTF-8 or ASCII: texts/text_1761689148709.txt
# Already UTF-8 or ASCII: texts/text_1761689148810.txt
# Already UTF-8 or ASCII: texts/text_1761689148962.txt
# Already UTF-8 or ASCII: texts/text_1761689149120.txt
# Already UTF-8 or ASCII: texts/text_1761689149221.txt
# Already UTF-8 or ASCII: texts/text_1761689149315.txt
# Converting texts/text_1761689149412.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689149412.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689149495.txt
# Already UTF-8 or ASCII: texts/text_1761689149573.txt
# Already UTF-8 or ASCII: texts/text_1761689149663.txt
# Already UTF-8 or ASCII: texts/text_1761689149735.txt
# Already UTF-8 or ASCII: texts/text_1761689149840.txt
# Already UTF-8 or ASCII: texts/text_1761689149954.txt
# Converting texts/text_1761689150069.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689150069.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689150202.txt
# Already UTF-8 or ASCII: texts/text_1761689150337.txt
# Converting texts/text_1761689150452.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689150452.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689150578.txt
# Already UTF-8 or ASCII: texts/text_1761689150704.txt
# Already UTF-8 or ASCII: texts/text_1761689150805.txt
# Already UTF-8 or ASCII: texts/text_1761689150905.txt
# Already UTF-8 or ASCII: texts/text_1761689151005.txt
# Already UTF-8 or ASCII: texts/text_1761689151110.txt
# Already UTF-8 or ASCII: texts/text_1761689151277.txt
# Already UTF-8 or ASCII: texts/text_1761689151401.txt
# Already UTF-8 or ASCII: texts/text_1761689151596.txt
# Already UTF-8 or ASCII: texts/text_1761689151791.txt
# Already UTF-8 or ASCII: texts/text_1761689152032.txt
# Already UTF-8 or ASCII: texts/text_1761689152232.txt
# Already UTF-8 or ASCII: texts/text_1761689152433.txt
# Already UTF-8 or ASCII: texts/text_1761689152606.txt
# Converting texts/text_1761689152816.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689152816.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689152991.txt
# Converting texts/text_1761689153767.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689153767.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689153950.txt
# Already UTF-8 or ASCII: texts/text_1761689154141.txt
# Already UTF-8 or ASCII: texts/text_1761689154295.txt
# Already UTF-8 or ASCII: texts/text_1761689154450.txt
# Already UTF-8 or ASCII: texts/text_1761689154714.txt
# Already UTF-8 or ASCII: texts/text_1761689155026.txt
# Converting texts/text_1761689155204.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689155204.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689155377.txt
# Converting texts/text_1761689155547.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689155547.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689155727.txt
# Already UTF-8 or ASCII: texts/text_1761689155876.txt
# Already UTF-8 or ASCII: texts/text_1761689156058.txt
# Already UTF-8 or ASCII: texts/text_1761689156251.txt
# Already UTF-8 or ASCII: texts/text_1761689156374.txt
# Converting texts/text_1761689156483.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689156483.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689156623.txt
# Already UTF-8 or ASCII: texts/text_1761689156766.txt
# Converting texts/text_1761689156912.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689156912.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689157048.txt
# Already UTF-8 or ASCII: texts/text_1761689157185.txt
# Already UTF-8 or ASCII: texts/text_1761689157301.txt
# Already UTF-8 or ASCII: texts/text_1761689157428.txt
# Already UTF-8 or ASCII: texts/text_1761689157588.txt
# Already UTF-8 or ASCII: texts/text_1761689157740.txt
# Converting texts/text_1761689157873.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689157873.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689157988.txt
# Already UTF-8 or ASCII: texts/text_1761689158137.txt
# Already UTF-8 or ASCII: texts/text_1761689158279.txt
# Already UTF-8 or ASCII: texts/text_1761689158406.txt
# Converting texts/text_1761689158526.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689158526.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689158662.txt
# Already UTF-8 or ASCII: texts/text_1761689158818.txt
# Already UTF-8 or ASCII: texts/text_1761689158953.txt
# Already UTF-8 or ASCII: texts/text_1761689159065.txt
# Already UTF-8 or ASCII: texts/text_1761689159147.txt
# Already UTF-8 or ASCII: texts/text_1761689159229.txt
# Already UTF-8 or ASCII: texts/text_1761689159319.txt
# Already UTF-8 or ASCII: texts/text_1761689159400.txt
# Converting texts/text_1761689159482.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689159482.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689159581.txt
# Already UTF-8 or ASCII: texts/text_1761689159661.txt
# Already UTF-8 or ASCII: texts/text_1761689159739.txt
# Already UTF-8 or ASCII: texts/text_1761689159827.txt
# Already UTF-8 or ASCII: texts/text_1761689159952.txt
# Already UTF-8 or ASCII: texts/text_1761689160059.txt
# Already UTF-8 or ASCII: texts/text_1761689160178.txt
# Already UTF-8 or ASCII: texts/text_1761689160315.txt
# Converting texts/text_1761689160469.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689160469.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689160606.txt
# Converting texts/text_1761689160740.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689160740.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689160874.txt
# Already UTF-8 or ASCII: texts/text_1761689161002.txt
# Already UTF-8 or ASCII: texts/text_1761689161118.txt
# Already UTF-8 or ASCII: texts/text_1761689161241.txt
# Already UTF-8 or ASCII: texts/text_1761689161343.txt
# Already UTF-8 or ASCII: texts/text_1761689161451.txt
# Already UTF-8 or ASCII: texts/text_1761689161657.txt
# Already UTF-8 or ASCII: texts/text_1761689161888.txt
# Already UTF-8 or ASCII: texts/text_1761689162138.txt
# Already UTF-8 or ASCII: texts/text_1761689162302.txt
# Already UTF-8 or ASCII: texts/text_1761689162528.txt
# Already UTF-8 or ASCII: texts/text_1761689162707.txt
# Converting texts/text_1761689162913.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689162913.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689163045.txt
# Already UTF-8 or ASCII: texts/text_1761689163187.txt
# Already UTF-8 or ASCII: texts/text_1761689163360.txt
# Converting texts/text_1761689163501.txt from MacRoman to UTF-8
# Re-encoded texts/text_1761689163501.txt successfully
# Already UTF-8 or ASCII: texts/text_1761689163643.txt
# Already UTF-8 or ASCII: texts/text_1761689163752.txt
# Already UTF-8 or ASCII: texts/text_1761689163840.txt
# Already UTF-8 or ASCII: texts/text_1761689163935.txt
# Already UTF-8 or ASCII: texts/text_1761689164028.txt
# Already UTF-8 or ASCII: texts/text_1761689164164.txt
# Already UTF-8 or ASCII: texts/text_1761689164265.txt
# Already UTF-8 or ASCII: texts/text_1761689164365.txt
# Already UTF-8 or ASCII: texts/text_1761689164506.txt
# Converting texts/text_1761689164657.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1761689164657.txt successfully
